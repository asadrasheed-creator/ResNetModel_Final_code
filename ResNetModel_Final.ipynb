# %%
import torch
import math
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
import torch.nn.functional as F
import time
import os
import torch.backends.cudnn as cudnn

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = '0'                # GPU Number 
start_time = time.time()
batch_size = 64
learning_rate = 0.08
root_dir = 'D:\Deeplearning/cifar10/'
default_directory = 'D:\Deeplearning/save_models'

# %%
# Data Augmentation
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),               # Random Position Crop
    transforms.RandomHorizontalFlip(),                  # right and left flip
    transforms.ToTensor(),                              # change [0,255] Int value to [0,1] Float value
    transforms.Normalize(mean=(0.4914, 0.4824, 0.4467), # RGB Normalize MEAN
                         std=(0.2471, 0.2436, 0.2616))  # RGB Normalize Standard Deviation
])

transform_test = transforms.Compose([
    transforms.ToTensor(),                              # change [0,255] Int value to [0,1] Float value
    transforms.Normalize(mean=(0.4914, 0.4824, 0.4467), # RGB Normalize MEAN
                         std=(0.2471, 0.2436, 0.2616))  # RGB Normalize Standard Deviation
])

# %%
# automatically download
train_dataset = datasets.CIFAR10(root=root_dir,
                                 train=True,
                                 transform=transform_train,
                                 download=True)

test_dataset = datasets.CIFAR10(root=root_dir,
                                train=False,
                                transform=transform_test)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True,            # at Training Procedure, Data Shuffle = True
                                           num_workers=8)           # CPU loader number

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False,            # at Test Procedure, Data Shuffle = False
                                          num_workers=8)            # CPU loader number
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to D:\Deeplearning/cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting D:\Deeplearning/cifar10/cifar-10-python.tar.gz to D:\Deeplearning/cifar10/

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = out + self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

# %%
model = ResNet(BasicBlock, [2, 2, 2, 2])
optimizer = optim.SGD(model.parameters(), learning_rate,
                                momentum=0.9,
                                weight_decay=1e-4,
                                nesterov=True)
criterion = nn.CrossEntropyLoss()

if torch.cuda.device_count() > 0:
    print("USE", torch.cuda.device_count(), "GPUs!")
    model = nn.DataParallel(model).cuda()
    cudnn.benchmark = True
else:
    print("USE ONLY CPU!")
# Out:
# USE 1 GPUs!

# %%
def train(epoch):
    model.train()
    train_loss = 0 
    total = 0
    correct = 0
    for batch_idx, (data, target) in enumerate(train_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        else:
            data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(output.data, 1)

        total += target.size(0)
        correct += predicted.eq(target.data).cpu().sum()
        if batch_idx % 10 == 0:
            print('Epoch: {} | Batch_idx: {} |  Loss: ({:.4f}) | Acc: ({:.2f}%) ({}/{})'
                  .format(epoch, batch_idx, train_loss / (batch_idx + 1), 100. * correct / total, correct, total))

# %%
def test():
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        if torch.cuda.is_available():
            data, target = Variable(data.cuda()), Variable(target.cuda())
        else:
            data, target = Variable(data), Variable(target)

        outputs = model(data)
        loss = criterion(outputs, target)

        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += target.size(0)
        correct += predicted.eq(target.data).cpu().sum()
    print('# TEST : Loss: ({:.4f}) | Acc: ({:.2f}%) ({}/{})'
          .format(test_loss / (batch_idx + 1), 100. * correct / total, correct, total))

# %%
def save_checkpoint(directory, state, filename='latest.tar.gz'):

    if not os.path.exists(directory):
        os.makedirs(directory)

    model_filename = os.path.join(directory, filename)
    torch.save(state, model_filename)
    print("=> saving checkpoint")

# %%
def load_checkpoint(directory, filename='latest.tar.gz'):

    model_filename = os.path.join(directory, filename)
    if os.path.exists(model_filename):
        print("=> loading checkpoint")
        state = torch.load(model_filename)
        return state
    else:
        return None

# %%
start_epoch = 0

checkpoint = load_checkpoint(default_directory)
if not checkpoint:
    pass
else:
    start_epoch = checkpoint['epoch'] + 1
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])

# %%
for epoch in range(start_epoch, 165):

    if epoch < 80:
        lr = learning_rate
    elif epoch < 120:
        lr = learning_rate * 0.1
    else:
        lr = learning_rate * 0.01
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

    train(epoch)
    save_checkpoint(default_directory, {
        'epoch': epoch,
        'model': model,
        'state_dict': model.state_dict(),
        'optimizer': optimizer.state_dict(),
    })
    test()  

now = time.gmtime(time.time() - start_time)
print('{} hours {} mins {} secs for training'.format(now.tm_hour, now.tm_min, now.tm_sec))
# Out:
# Epoch: 0 | Batch_idx: 0 |  Loss: (2.3096) | Acc: (4.69%) (3/64)
# Epoch: 0 | Batch_idx: 10 |  Loss: (11.1998) | Acc: (9.80%) (69/704)
# Epoch: 0 | Batch_idx: 20 |  Loss: (8.6948) | Acc: (11.46%) (154/1344)
# Epoch: 0 | Batch_idx: 30 |  Loss: (7.4348) | Acc: (11.69%) (232/1984)
# Epoch: 0 | Batch_idx: 40 |  Loss: (6.5958) | Acc: (11.78%) (309/2624)
# Epoch: 0 | Batch_idx: 50 |  Loss: (5.9979) | Acc: (11.73%) (383/3264)
# Epoch: 0 | Batch_idx: 60 |  Loss: (5.5125) | Acc: (12.09%) (472/3904)
# Epoch: 0 | Batch_idx: 70 |  Loss: (5.0790) | Acc: (13.16%) (598/4544)
# Epoch: 0 | Batch_idx: 80 |  Loss: (4.7523) | Acc: (14.00%) (726/5184)
# Epoch: 0 | Batch_idx: 90 |  Loss: (4.4891) | Acc: (14.13%) (823/5824)
# Epoch: 0 | Batch_idx: 100 |  Loss: (4.2934) | Acc: (14.81%) (957/6464)
# Epoch: 0 | Batch_idx: 110 |  Loss: (4.1063) | Acc: (15.48%) (1100/7104)
# Epoch: 0 | Batch_idx: 120 |  Loss: (3.9559) | Acc: (15.74%) (1219/7744)
# Epoch: 0 | Batch_idx: 130 |  Loss: (3.8255) | Acc: (15.99%) (1341/8384)
# Epoch: 0 | Batch_idx: 140 |  Loss: (3.7061) | Acc: (16.42%) (1482/9024)
# Epoch: 0 | Batch_idx: 150 |  Loss: (3.6098) | Acc: (16.51%) (1596/9664)
# Epoch: 0 | Batch_idx: 160 |  Loss: (3.5146) | Acc: (16.85%) (1736/10304)
# Epoch: 0 | Batch_idx: 170 |  Loss: (3.4312) | Acc: (17.18%) (1880/10944)
# Epoch: 0 | Batch_idx: 180 |  Loss: (3.3576) | Acc: (17.53%) (2031/11584)
# Epoch: 0 | Batch_idx: 190 |  Loss: (3.2954) | Acc: (17.81%) (2177/12224)
# Epoch: 0 | Batch_idx: 200 |  Loss: (3.2376) | Acc: (18.15%) (2335/12864)
# Epoch: 0 | Batch_idx: 210 |  Loss: (3.1812) | Acc: (18.47%) (2494/13504)
# Epoch: 0 | Batch_idx: 220 |  Loss: (3.1287) | Acc: (18.75%) (2652/14144)
# Epoch: 0 | Batch_idx: 230 |  Loss: (3.0811) | Acc: (18.93%) (2799/14784)
# Epoch: 0 | Batch_idx: 240 |  Loss: (3.0391) | Acc: (19.21%) (2963/15424)
# Epoch: 0 | Batch_idx: 250 |  Loss: (2.9980) | Acc: (19.43%) (3122/16064)
# Epoch: 0 | Batch_idx: 260 |  Loss: (2.9618) | Acc: (19.59%) (3272/16704)
# Epoch: 0 | Batch_idx: 270 |  Loss: (2.9272) | Acc: (19.76%) (3427/17344)
# Epoch: 0 | Batch_idx: 280 |  Loss: (2.8959) | Acc: (20.00%) (3596/17984)
# Epoch: 0 | Batch_idx: 290 |  Loss: (2.8633) | Acc: (20.18%) (3758/18624)
# Epoch: 0 | Batch_idx: 300 |  Loss: (2.8323) | Acc: (20.59%) (3966/19264)
# Epoch: 0 | Batch_idx: 310 |  Loss: (2.8049) | Acc: (20.75%) (4131/19904)
# Epoch: 0 | Batch_idx: 320 |  Loss: (2.7767) | Acc: (21.05%) (4324/20544)
# Epoch: 0 | Batch_idx: 330 |  Loss: (2.7519) | Acc: (21.23%) (4497/21184)
# Epoch: 0 | Batch_idx: 340 |  Loss: (2.7275) | Acc: (21.45%) (4682/21824)
# Epoch: 0 | Batch_idx: 350 |  Loss: (2.7028) | Acc: (21.75%) (4887/22464)
# Epoch: 0 | Batch_idx: 360 |  Loss: (2.6807) | Acc: (21.97%) (5076/23104)
# Epoch: 0 | Batch_idx: 370 |  Loss: (2.6583) | Acc: (22.26%) (5286/23744)
# Epoch: 0 | Batch_idx: 380 |  Loss: (2.6365) | Acc: (22.52%) (5491/24384)
# Epoch: 0 | Batch_idx: 390 |  Loss: (2.6164) | Acc: (22.81%) (5707/25024)
# Epoch: 0 | Batch_idx: 400 |  Loss: (2.5984) | Acc: (23.02%) (5909/25664)
# Epoch: 0 | Batch_idx: 410 |  Loss: (2.5795) | Acc: (23.30%) (6130/26304)
# Epoch: 0 | Batch_idx: 420 |  Loss: (2.5612) | Acc: (23.59%) (6356/26944)
# Epoch: 0 | Batch_idx: 430 |  Loss: (2.5454) | Acc: (23.77%) (6558/27584)
# Epoch: 0 | Batch_idx: 440 |  Loss: (2.5288) | Acc: (23.95%) (6760/28224)
# Epoch: 0 | Batch_idx: 450 |  Loss: (2.5121) | Acc: (24.23%) (6994/28864)
# Epoch: 0 | Batch_idx: 460 |  Loss: (2.4962) | Acc: (24.47%) (7220/29504)
# Epoch: 0 | Batch_idx: 470 |  Loss: (2.4819) | Acc: (24.65%) (7431/30144)
# Epoch: 0 | Batch_idx: 480 |  Loss: (2.4675) | Acc: (24.81%) (7636/30784)
# Epoch: 0 | Batch_idx: 490 |  Loss: (2.4530) | Acc: (25.04%) (7868/31424)
# Epoch: 0 | Batch_idx: 500 |  Loss: (2.4396) | Acc: (25.21%) (8084/32064)
# Epoch: 0 | Batch_idx: 510 |  Loss: (2.4274) | Acc: (25.37%) (8297/32704)
# Epoch: 0 | Batch_idx: 520 |  Loss: (2.4143) | Acc: (25.61%) (8538/33344)
# Epoch: 0 | Batch_idx: 530 |  Loss: (2.4008) | Acc: (25.80%) (8768/33984)
# Epoch: 0 | Batch_idx: 540 |  Loss: (2.3902) | Acc: (25.94%) (8981/34624)
# Epoch: 0 | Batch_idx: 550 |  Loss: (2.3794) | Acc: (26.06%) (9189/35264)
# Epoch: 0 | Batch_idx: 560 |  Loss: (2.3683) | Acc: (26.23%) (9416/35904)
# Epoch: 0 | Batch_idx: 570 |  Loss: (2.3576) | Acc: (26.38%) (9642/36544)
# Epoch: 0 | Batch_idx: 580 |  Loss: (2.3472) | Acc: (26.50%) (9852/37184)
# Epoch: 0 | Batch_idx: 590 |  Loss: (2.3369) | Acc: (26.67%) (10088/37824)
# Epoch: 0 | Batch_idx: 600 |  Loss: (2.3257) | Acc: (26.86%) (10331/38464)
# Epoch: 0 | Batch_idx: 610 |  Loss: (2.3144) | Acc: (27.09%) (10595/39104)
# Epoch: 0 | Batch_idx: 620 |  Loss: (2.3040) | Acc: (27.32%) (10858/39744)
# Epoch: 0 | Batch_idx: 630 |  Loss: (2.2953) | Acc: (27.44%) (11080/40384)
# Epoch: 0 | Batch_idx: 640 |  Loss: (2.2864) | Acc: (27.61%) (11326/41024)
# Epoch: 0 | Batch_idx: 650 |  Loss: (2.2790) | Acc: (27.75%) (11561/41664)
# Epoch: 0 | Batch_idx: 660 |  Loss: (2.2692) | Acc: (27.95%) (11824/42304)
# Epoch: 0 | Batch_idx: 670 |  Loss: (2.2606) | Acc: (28.10%) (12068/42944)
# Epoch: 0 | Batch_idx: 680 |  Loss: (2.2518) | Acc: (28.29%) (12329/43584)
# Epoch: 0 | Batch_idx: 690 |  Loss: (2.2440) | Acc: (28.40%) (12561/44224)
# Epoch: 0 | Batch_idx: 700 |  Loss: (2.2358) | Acc: (28.56%) (12814/44864)
# Epoch: 0 | Batch_idx: 710 |  Loss: (2.2272) | Acc: (28.75%) (13084/45504)
# Epoch: 0 | Batch_idx: 720 |  Loss: (2.2187) | Acc: (28.93%) (13351/46144)
# Epoch: 0 | Batch_idx: 730 |  Loss: (2.2106) | Acc: (29.08%) (13603/46784)
# Epoch: 0 | Batch_idx: 740 |  Loss: (2.2031) | Acc: (29.26%) (13878/47424)
# Epoch: 0 | Batch_idx: 750 |  Loss: (2.1959) | Acc: (29.42%) (14142/48064)
# Epoch: 0 | Batch_idx: 760 |  Loss: (2.1880) | Acc: (29.59%) (14412/48704)
# Epoch: 0 | Batch_idx: 770 |  Loss: (2.1814) | Acc: (29.71%) (14658/49344)
# Epoch: 0 | Batch_idx: 780 |  Loss: (2.1734) | Acc: (29.87%) (14932/49984)
# => saving checkpoint
# # TEST : Loss: (1.6644) | Acc: (38.57%) (3857/10000)
# Epoch: 1 | Batch_idx: 0 |  Loss: (1.8257) | Acc: (40.62%) (26/64)
# Epoch: 1 | Batch_idx: 10 |  Loss: (1.6121) | Acc: (41.48%) (292/704)
# Epoch: 1 | Batch_idx: 20 |  Loss: (1.6525) | Acc: (39.96%) (537/1344)
# Epoch: 1 | Batch_idx: 30 |  Loss: (1.6307) | Acc: (40.68%) (807/1984)
# Epoch: 1 | Batch_idx: 40 |  Loss: (1.6210) | Acc: (41.69%) (1094/2624)
# Epoch: 1 | Batch_idx: 50 |  Loss: (1.6232) | Acc: (41.15%) (1343/3264)
# Epoch: 1 | Batch_idx: 60 |  Loss: (1.6189) | Acc: (41.16%) (1607/3904)
# Epoch: 1 | Batch_idx: 70 |  Loss: (1.6148) | Acc: (41.29%) (1876/4544)
# Epoch: 1 | Batch_idx: 80 |  Loss: (1.6163) | Acc: (41.07%) (2129/5184)
# Epoch: 1 | Batch_idx: 90 |  Loss: (1.6167) | Acc: (41.16%) (2397/5824)
# Epoch: 1 | Batch_idx: 100 |  Loss: (1.6123) | Acc: (41.27%) (2668/6464)
# Epoch: 1 | Batch_idx: 110 |  Loss: (1.6079) | Acc: (41.50%) (2948/7104)
# Epoch: 1 | Batch_idx: 120 |  Loss: (1.6033) | Acc: (41.84%) (3240/7744)
# Epoch: 1 | Batch_idx: 130 |  Loss: (1.6025) | Acc: (41.75%) (3500/8384)
# Epoch: 1 | Batch_idx: 140 |  Loss: (1.6003) | Acc: (41.71%) (3764/9024)
# Epoch: 1 | Batch_idx: 150 |  Loss: (1.5973) | Acc: (41.77%) (4037/9664)
# Epoch: 1 | Batch_idx: 160 |  Loss: (1.5966) | Acc: (41.84%) (4311/10304)
# Epoch: 1 | Batch_idx: 170 |  Loss: (1.5985) | Acc: (41.76%) (4570/10944)
# Epoch: 1 | Batch_idx: 180 |  Loss: (1.5947) | Acc: (41.82%) (4844/11584)
# Epoch: 1 | Batch_idx: 190 |  Loss: (1.5905) | Acc: (41.97%) (5130/12224)
# Epoch: 1 | Batch_idx: 200 |  Loss: (1.5919) | Acc: (41.91%) (5391/12864)
# Epoch: 1 | Batch_idx: 210 |  Loss: (1.5901) | Acc: (42.00%) (5672/13504)
# Epoch: 1 | Batch_idx: 220 |  Loss: (1.5881) | Acc: (42.01%) (5942/14144)
# Epoch: 1 | Batch_idx: 230 |  Loss: (1.5874) | Acc: (42.09%) (6222/14784)
# Epoch: 1 | Batch_idx: 240 |  Loss: (1.5823) | Acc: (42.16%) (6503/15424)
# Epoch: 1 | Batch_idx: 250 |  Loss: (1.5802) | Acc: (42.19%) (6778/16064)
# Epoch: 1 | Batch_idx: 260 |  Loss: (1.5758) | Acc: (42.34%) (7072/16704)
# Epoch: 1 | Batch_idx: 270 |  Loss: (1.5750) | Acc: (42.39%) (7352/17344)
# Epoch: 1 | Batch_idx: 280 |  Loss: (1.5737) | Acc: (42.48%) (7639/17984)
# Epoch: 1 | Batch_idx: 290 |  Loss: (1.5700) | Acc: (42.58%) (7931/18624)
# Epoch: 1 | Batch_idx: 300 |  Loss: (1.5680) | Acc: (42.66%) (8218/19264)
# Epoch: 1 | Batch_idx: 310 |  Loss: (1.5635) | Acc: (42.81%) (8521/19904)
# Epoch: 1 | Batch_idx: 320 |  Loss: (1.5627) | Acc: (42.88%) (8809/20544)
# Epoch: 1 | Batch_idx: 330 |  Loss: (1.5590) | Acc: (43.02%) (9113/21184)
# Epoch: 1 | Batch_idx: 340 |  Loss: (1.5574) | Acc: (43.10%) (9406/21824)
# Epoch: 1 | Batch_idx: 350 |  Loss: (1.5553) | Acc: (43.20%) (9705/22464)
# Epoch: 1 | Batch_idx: 360 |  Loss: (1.5536) | Acc: (43.24%) (9990/23104)
# Epoch: 1 | Batch_idx: 370 |  Loss: (1.5519) | Acc: (43.24%) (10268/23744)
# Epoch: 1 | Batch_idx: 380 |  Loss: (1.5481) | Acc: (43.42%) (10588/24384)
# Epoch: 1 | Batch_idx: 390 |  Loss: (1.5459) | Acc: (43.45%) (10872/25024)
# Epoch: 1 | Batch_idx: 400 |  Loss: (1.5457) | Acc: (43.46%) (11153/25664)
# Epoch: 1 | Batch_idx: 410 |  Loss: (1.5429) | Acc: (43.59%) (11466/26304)
# Epoch: 1 | Batch_idx: 420 |  Loss: (1.5416) | Acc: (43.64%) (11758/26944)
# Epoch: 1 | Batch_idx: 430 |  Loss: (1.5393) | Acc: (43.74%) (12065/27584)
# Epoch: 1 | Batch_idx: 440 |  Loss: (1.5379) | Acc: (43.82%) (12369/28224)
# Epoch: 1 | Batch_idx: 450 |  Loss: (1.5346) | Acc: (43.95%) (12686/28864)
# Epoch: 1 | Batch_idx: 460 |  Loss: (1.5320) | Acc: (44.11%) (13015/29504)
# Epoch: 1 | Batch_idx: 470 |  Loss: (1.5297) | Acc: (44.13%) (13302/30144)
# Epoch: 1 | Batch_idx: 480 |  Loss: (1.5266) | Acc: (44.26%) (13624/30784)
# Epoch: 1 | Batch_idx: 490 |  Loss: (1.5245) | Acc: (44.33%) (13930/31424)
# Epoch: 1 | Batch_idx: 500 |  Loss: (1.5226) | Acc: (44.34%) (14218/32064)
# Epoch: 1 | Batch_idx: 510 |  Loss: (1.5205) | Acc: (44.44%) (14533/32704)
# Epoch: 1 | Batch_idx: 520 |  Loss: (1.5181) | Acc: (44.53%) (14848/33344)
# Epoch: 1 | Batch_idx: 530 |  Loss: (1.5155) | Acc: (44.61%) (15159/33984)
# Epoch: 1 | Batch_idx: 540 |  Loss: (1.5130) | Acc: (44.68%) (15471/34624)
# Epoch: 1 | Batch_idx: 550 |  Loss: (1.5118) | Acc: (44.74%) (15776/35264)
# Epoch: 1 | Batch_idx: 560 |  Loss: (1.5109) | Acc: (44.76%) (16072/35904)
# Epoch: 1 | Batch_idx: 570 |  Loss: (1.5096) | Acc: (44.84%) (16387/36544)
# Epoch: 1 | Batch_idx: 580 |  Loss: (1.5072) | Acc: (44.91%) (16699/37184)
# Epoch: 1 | Batch_idx: 590 |  Loss: (1.5043) | Acc: (44.99%) (17017/37824)
# Epoch: 1 | Batch_idx: 600 |  Loss: (1.5013) | Acc: (45.11%) (17350/38464)
# Epoch: 1 | Batch_idx: 610 |  Loss: (1.4992) | Acc: (45.18%) (17668/39104)
# Epoch: 1 | Batch_idx: 620 |  Loss: (1.4964) | Acc: (45.30%) (18004/39744)
# Epoch: 1 | Batch_idx: 630 |  Loss: (1.4930) | Acc: (45.40%) (18336/40384)
# Epoch: 1 | Batch_idx: 640 |  Loss: (1.4904) | Acc: (45.50%) (18666/41024)
# Epoch: 1 | Batch_idx: 650 |  Loss: (1.4877) | Acc: (45.58%) (18992/41664)
# Epoch: 1 | Batch_idx: 660 |  Loss: (1.4866) | Acc: (45.63%) (19302/42304)
# Epoch: 1 | Batch_idx: 670 |  Loss: (1.4843) | Acc: (45.72%) (19633/42944)
# Epoch: 1 | Batch_idx: 680 |  Loss: (1.4814) | Acc: (45.80%) (19963/43584)
# Epoch: 1 | Batch_idx: 690 |  Loss: (1.4800) | Acc: (45.87%) (20284/44224)
# Epoch: 1 | Batch_idx: 700 |  Loss: (1.4779) | Acc: (45.94%) (20612/44864)
# Epoch: 1 | Batch_idx: 710 |  Loss: (1.4740) | Acc: (46.10%) (20977/45504)
# Epoch: 1 | Batch_idx: 720 |  Loss: (1.4720) | Acc: (46.16%) (21301/46144)
# Epoch: 1 | Batch_idx: 730 |  Loss: (1.4696) | Acc: (46.27%) (21645/46784)
# Epoch: 1 | Batch_idx: 740 |  Loss: (1.4681) | Acc: (46.31%) (21963/47424)
# Epoch: 1 | Batch_idx: 750 |  Loss: (1.4648) | Acc: (46.44%) (22321/48064)
# Epoch: 1 | Batch_idx: 760 |  Loss: (1.4621) | Acc: (46.53%) (22660/48704)
# Epoch: 1 | Batch_idx: 770 |  Loss: (1.4598) | Acc: (46.64%) (23014/49344)
# Epoch: 1 | Batch_idx: 780 |  Loss: (1.4580) | Acc: (46.72%) (23352/49984)
# => saving checkpoint
# # TEST : Loss: (1.2797) | Acc: (53.79%) (5379/10000)
# Epoch: 2 | Batch_idx: 0 |  Loss: (1.3688) | Acc: (53.12%) (34/64)
# Epoch: 2 | Batch_idx: 10 |  Loss: (1.2713) | Acc: (54.12%) (381/704)
# Epoch: 2 | Batch_idx: 20 |  Loss: (1.2912) | Acc: (52.90%) (711/1344)
# Epoch: 2 | Batch_idx: 30 |  Loss: (1.2852) | Acc: (53.58%) (1063/1984)
# Epoch: 2 | Batch_idx: 40 |  Loss: (1.2875) | Acc: (53.51%) (1404/2624)
# Epoch: 2 | Batch_idx: 50 |  Loss: (1.2662) | Acc: (54.29%) (1772/3264)
# Epoch: 2 | Batch_idx: 60 |  Loss: (1.2668) | Acc: (54.61%) (2132/3904)
# Epoch: 2 | Batch_idx: 70 |  Loss: (1.2568) | Acc: (54.75%) (2488/4544)
# Epoch: 2 | Batch_idx: 80 |  Loss: (1.2532) | Acc: (55.09%) (2856/5184)
# Epoch: 2 | Batch_idx: 90 |  Loss: (1.2531) | Acc: (54.86%) (3195/5824)
# Epoch: 2 | Batch_idx: 100 |  Loss: (1.2526) | Acc: (54.72%) (3537/6464)
# Epoch: 2 | Batch_idx: 110 |  Loss: (1.2531) | Acc: (54.65%) (3882/7104)
# Epoch: 2 | Batch_idx: 120 |  Loss: (1.2518) | Acc: (54.91%) (4252/7744)
# Epoch: 2 | Batch_idx: 130 |  Loss: (1.2532) | Acc: (54.90%) (4603/8384)
# Epoch: 2 | Batch_idx: 140 |  Loss: (1.2589) | Acc: (54.67%) (4933/9024)
# Epoch: 2 | Batch_idx: 150 |  Loss: (1.2551) | Acc: (54.84%) (5300/9664)
# Epoch: 2 | Batch_idx: 160 |  Loss: (1.2510) | Acc: (55.14%) (5682/10304)
# Epoch: 2 | Batch_idx: 170 |  Loss: (1.2499) | Acc: (55.12%) (6032/10944)
# Epoch: 2 | Batch_idx: 180 |  Loss: (1.2466) | Acc: (55.25%) (6400/11584)
# Epoch: 2 | Batch_idx: 190 |  Loss: (1.2459) | Acc: (55.39%) (6771/12224)
# Epoch: 2 | Batch_idx: 200 |  Loss: (1.2450) | Acc: (55.55%) (7146/12864)
# Epoch: 2 | Batch_idx: 210 |  Loss: (1.2405) | Acc: (55.63%) (7512/13504)
# Epoch: 2 | Batch_idx: 220 |  Loss: (1.2383) | Acc: (55.65%) (7871/14144)
# Epoch: 2 | Batch_idx: 230 |  Loss: (1.2397) | Acc: (55.61%) (8221/14784)
# Epoch: 2 | Batch_idx: 240 |  Loss: (1.2399) | Acc: (55.57%) (8571/15424)
# Epoch: 2 | Batch_idx: 250 |  Loss: (1.2363) | Acc: (55.71%) (8949/16064)
# Epoch: 2 | Batch_idx: 260 |  Loss: (1.2341) | Acc: (55.74%) (9310/16704)
# Epoch: 2 | Batch_idx: 270 |  Loss: (1.2312) | Acc: (55.83%) (9683/17344)
# Epoch: 2 | Batch_idx: 280 |  Loss: (1.2296) | Acc: (55.94%) (10060/17984)
# Epoch: 2 | Batch_idx: 290 |  Loss: (1.2284) | Acc: (56.04%) (10437/18624)
# Epoch: 2 | Batch_idx: 300 |  Loss: (1.2278) | Acc: (56.06%) (10799/19264)
# Epoch: 2 | Batch_idx: 310 |  Loss: (1.2241) | Acc: (56.20%) (11186/19904)
# Epoch: 2 | Batch_idx: 320 |  Loss: (1.2225) | Acc: (56.24%) (11553/20544)
# Epoch: 2 | Batch_idx: 330 |  Loss: (1.2186) | Acc: (56.30%) (11927/21184)
# Epoch: 2 | Batch_idx: 340 |  Loss: (1.2191) | Acc: (56.27%) (12280/21824)
# Epoch: 2 | Batch_idx: 350 |  Loss: (1.2190) | Acc: (56.26%) (12639/22464)
# Epoch: 2 | Batch_idx: 360 |  Loss: (1.2160) | Acc: (56.41%) (13033/23104)
# Epoch: 2 | Batch_idx: 370 |  Loss: (1.2128) | Acc: (56.54%) (13424/23744)
# Epoch: 2 | Batch_idx: 380 |  Loss: (1.2111) | Acc: (56.60%) (13802/24384)
# Epoch: 2 | Batch_idx: 390 |  Loss: (1.2085) | Acc: (56.69%) (14187/25024)
# Epoch: 2 | Batch_idx: 400 |  Loss: (1.2085) | Acc: (56.66%) (14540/25664)
# Epoch: 2 | Batch_idx: 410 |  Loss: (1.2062) | Acc: (56.74%) (14926/26304)
# Epoch: 2 | Batch_idx: 420 |  Loss: (1.2043) | Acc: (56.80%) (15303/26944)
# Epoch: 2 | Batch_idx: 430 |  Loss: (1.2025) | Acc: (56.93%) (15703/27584)
# Epoch: 2 | Batch_idx: 440 |  Loss: (1.2015) | Acc: (56.97%) (16079/28224)
# Epoch: 2 | Batch_idx: 450 |  Loss: (1.1999) | Acc: (57.02%) (16457/28864)
# Epoch: 2 | Batch_idx: 460 |  Loss: (1.1997) | Acc: (57.06%) (16835/29504)
# Epoch: 2 | Batch_idx: 470 |  Loss: (1.1973) | Acc: (57.16%) (17229/30144)
# Epoch: 2 | Batch_idx: 480 |  Loss: (1.1970) | Acc: (57.19%) (17604/30784)
# Epoch: 2 | Batch_idx: 490 |  Loss: (1.1949) | Acc: (57.30%) (18005/31424)
# Epoch: 2 | Batch_idx: 500 |  Loss: (1.1922) | Acc: (57.42%) (18412/32064)
# Epoch: 2 | Batch_idx: 510 |  Loss: (1.1905) | Acc: (57.48%) (18797/32704)
# Epoch: 2 | Batch_idx: 520 |  Loss: (1.1901) | Acc: (57.50%) (19173/33344)
# Epoch: 2 | Batch_idx: 530 |  Loss: (1.1871) | Acc: (57.58%) (19568/33984)
# Epoch: 2 | Batch_idx: 540 |  Loss: (1.1853) | Acc: (57.64%) (19956/34624)
# Epoch: 2 | Batch_idx: 550 |  Loss: (1.1838) | Acc: (57.69%) (20344/35264)
# Epoch: 2 | Batch_idx: 560 |  Loss: (1.1810) | Acc: (57.78%) (20747/35904)
# Epoch: 2 | Batch_idx: 570 |  Loss: (1.1793) | Acc: (57.85%) (21140/36544)
# Epoch: 2 | Batch_idx: 580 |  Loss: (1.1774) | Acc: (57.94%) (21543/37184)
# Epoch: 2 | Batch_idx: 590 |  Loss: (1.1756) | Acc: (58.00%) (21938/37824)
# Epoch: 2 | Batch_idx: 600 |  Loss: (1.1740) | Acc: (58.07%) (22335/38464)
# Epoch: 2 | Batch_idx: 610 |  Loss: (1.1735) | Acc: (58.10%) (22721/39104)
# Epoch: 2 | Batch_idx: 620 |  Loss: (1.1725) | Acc: (58.15%) (23111/39744)
# Epoch: 2 | Batch_idx: 630 |  Loss: (1.1703) | Acc: (58.21%) (23507/40384)
# Epoch: 2 | Batch_idx: 640 |  Loss: (1.1688) | Acc: (58.27%) (23906/41024)
# Epoch: 2 | Batch_idx: 650 |  Loss: (1.1663) | Acc: (58.36%) (24317/41664)
# Epoch: 2 | Batch_idx: 660 |  Loss: (1.1644) | Acc: (58.42%) (24713/42304)
# Epoch: 2 | Batch_idx: 670 |  Loss: (1.1623) | Acc: (58.53%) (25137/42944)
# Epoch: 2 | Batch_idx: 680 |  Loss: (1.1609) | Acc: (58.61%) (25543/43584)
# Epoch: 2 | Batch_idx: 690 |  Loss: (1.1598) | Acc: (58.64%) (25932/44224)
# Epoch: 2 | Batch_idx: 700 |  Loss: (1.1584) | Acc: (58.66%) (26318/44864)
# Epoch: 2 | Batch_idx: 710 |  Loss: (1.1571) | Acc: (58.71%) (26716/45504)
# Epoch: 2 | Batch_idx: 720 |  Loss: (1.1558) | Acc: (58.74%) (27107/46144)
# Epoch: 2 | Batch_idx: 730 |  Loss: (1.1558) | Acc: (58.74%) (27479/46784)
# Epoch: 2 | Batch_idx: 740 |  Loss: (1.1546) | Acc: (58.77%) (27871/47424)
# Epoch: 2 | Batch_idx: 750 |  Loss: (1.1520) | Acc: (58.86%) (28292/48064)
# Epoch: 2 | Batch_idx: 760 |  Loss: (1.1512) | Acc: (58.90%) (28686/48704)
# Epoch: 2 | Batch_idx: 770 |  Loss: (1.1495) | Acc: (58.97%) (29096/49344)
# Epoch: 2 | Batch_idx: 780 |  Loss: (1.1487) | Acc: (58.99%) (29486/49984)
# => saving checkpoint
# # TEST : Loss: (1.2001) | Acc: (57.57%) (5757/10000)
# Epoch: 3 | Batch_idx: 0 |  Loss: (0.8756) | Acc: (70.31%) (45/64)
# Epoch: 3 | Batch_idx: 10 |  Loss: (1.0120) | Acc: (63.92%) (450/704)
# Epoch: 3 | Batch_idx: 20 |  Loss: (1.0375) | Acc: (62.43%) (839/1344)
# Epoch: 3 | Batch_idx: 30 |  Loss: (1.0737) | Acc: (61.64%) (1223/1984)
# Epoch: 3 | Batch_idx: 40 |  Loss: (1.0589) | Acc: (62.16%) (1631/2624)
# Epoch: 3 | Batch_idx: 50 |  Loss: (1.0440) | Acc: (62.56%) (2042/3264)
# Epoch: 3 | Batch_idx: 60 |  Loss: (1.0367) | Acc: (63.01%) (2460/3904)
# Epoch: 3 | Batch_idx: 70 |  Loss: (1.0416) | Acc: (62.70%) (2849/4544)
# Epoch: 3 | Batch_idx: 80 |  Loss: (1.0431) | Acc: (62.79%) (3255/5184)
# Epoch: 3 | Batch_idx: 90 |  Loss: (1.0422) | Acc: (62.84%) (3660/5824)
# Epoch: 3 | Batch_idx: 100 |  Loss: (1.0436) | Acc: (62.90%) (4066/6464)
# Epoch: 3 | Batch_idx: 110 |  Loss: (1.0422) | Acc: (63.06%) (4480/7104)
# Epoch: 3 | Batch_idx: 120 |  Loss: (1.0325) | Acc: (63.34%) (4905/7744)
# Epoch: 3 | Batch_idx: 130 |  Loss: (1.0288) | Acc: (63.43%) (5318/8384)
# Epoch: 3 | Batch_idx: 140 |  Loss: (1.0244) | Acc: (63.50%) (5730/9024)
# Epoch: 3 | Batch_idx: 150 |  Loss: (1.0233) | Acc: (63.56%) (6142/9664)
# Epoch: 3 | Batch_idx: 160 |  Loss: (1.0180) | Acc: (63.73%) (6567/10304)
# Epoch: 3 | Batch_idx: 170 |  Loss: (1.0167) | Acc: (63.67%) (6968/10944)
# Epoch: 3 | Batch_idx: 180 |  Loss: (1.0158) | Acc: (63.82%) (7393/11584)
# Epoch: 3 | Batch_idx: 190 |  Loss: (1.0131) | Acc: (63.84%) (7804/12224)
# Epoch: 3 | Batch_idx: 200 |  Loss: (1.0117) | Acc: (63.87%) (8216/12864)
# Epoch: 3 | Batch_idx: 210 |  Loss: (1.0147) | Acc: (63.67%) (8598/13504)
# Epoch: 3 | Batch_idx: 220 |  Loss: (1.0131) | Acc: (63.82%) (9027/14144)
# Epoch: 3 | Batch_idx: 230 |  Loss: (1.0069) | Acc: (64.10%) (9476/14784)
# Epoch: 3 | Batch_idx: 240 |  Loss: (1.0052) | Acc: (64.11%) (9888/15424)
# Epoch: 3 | Batch_idx: 250 |  Loss: (1.0056) | Acc: (64.10%) (10297/16064)
# Epoch: 3 | Batch_idx: 260 |  Loss: (1.0055) | Acc: (64.08%) (10704/16704)
# Epoch: 3 | Batch_idx: 270 |  Loss: (1.0049) | Acc: (64.08%) (11114/17344)
# Epoch: 3 | Batch_idx: 280 |  Loss: (1.0058) | Acc: (64.08%) (11524/17984)
# Epoch: 3 | Batch_idx: 290 |  Loss: (1.0051) | Acc: (64.07%) (11933/18624)
# Epoch: 3 | Batch_idx: 300 |  Loss: (1.0021) | Acc: (64.15%) (12357/19264)
# Epoch: 3 | Batch_idx: 310 |  Loss: (1.0008) | Acc: (64.13%) (12764/19904)
# Epoch: 3 | Batch_idx: 320 |  Loss: (1.0022) | Acc: (64.11%) (13171/20544)
# Epoch: 3 | Batch_idx: 330 |  Loss: (1.0003) | Acc: (64.17%) (13593/21184)
# Epoch: 3 | Batch_idx: 340 |  Loss: (0.9990) | Acc: (64.21%) (14014/21824)
# Epoch: 3 | Batch_idx: 350 |  Loss: (0.9981) | Acc: (64.28%) (14439/22464)
# Epoch: 3 | Batch_idx: 360 |  Loss: (0.9991) | Acc: (64.27%) (14848/23104)
# Epoch: 3 | Batch_idx: 370 |  Loss: (0.9975) | Acc: (64.29%) (15265/23744)
# Epoch: 3 | Batch_idx: 380 |  Loss: (0.9961) | Acc: (64.35%) (15692/24384)
# Epoch: 3 | Batch_idx: 390 |  Loss: (0.9935) | Acc: (64.51%) (16143/25024)
# Epoch: 3 | Batch_idx: 400 |  Loss: (0.9925) | Acc: (64.52%) (16559/25664)
# Epoch: 3 | Batch_idx: 410 |  Loss: (0.9895) | Acc: (64.66%) (17008/26304)
# Epoch: 3 | Batch_idx: 420 |  Loss: (0.9867) | Acc: (64.73%) (17442/26944)
# Epoch: 3 | Batch_idx: 430 |  Loss: (0.9852) | Acc: (64.82%) (17879/27584)
# Epoch: 3 | Batch_idx: 440 |  Loss: (0.9856) | Acc: (64.77%) (18282/28224)
# Epoch: 3 | Batch_idx: 450 |  Loss: (0.9846) | Acc: (64.85%) (18717/28864)
# Epoch: 3 | Batch_idx: 460 |  Loss: (0.9828) | Acc: (64.91%) (19150/29504)
# Epoch: 3 | Batch_idx: 470 |  Loss: (0.9822) | Acc: (64.99%) (19591/30144)
# Epoch: 3 | Batch_idx: 480 |  Loss: (0.9824) | Acc: (64.97%) (20000/30784)
# Epoch: 3 | Batch_idx: 490 |  Loss: (0.9807) | Acc: (65.01%) (20430/31424)
# Epoch: 3 | Batch_idx: 500 |  Loss: (0.9800) | Acc: (65.06%) (20861/32064)
# Epoch: 3 | Batch_idx: 510 |  Loss: (0.9774) | Acc: (65.16%) (21311/32704)
# Epoch: 3 | Batch_idx: 520 |  Loss: (0.9770) | Acc: (65.16%) (21726/33344)
# Epoch: 3 | Batch_idx: 530 |  Loss: (0.9751) | Acc: (65.25%) (22174/33984)
# Epoch: 3 | Batch_idx: 540 |  Loss: (0.9745) | Acc: (65.24%) (22588/34624)
# Epoch: 3 | Batch_idx: 550 |  Loss: (0.9743) | Acc: (65.24%) (23007/35264)
# Epoch: 3 | Batch_idx: 560 |  Loss: (0.9739) | Acc: (65.28%) (23438/35904)
# Epoch: 3 | Batch_idx: 570 |  Loss: (0.9731) | Acc: (65.33%) (23875/36544)
# Epoch: 3 | Batch_idx: 580 |  Loss: (0.9724) | Acc: (65.38%) (24310/37184)
# Epoch: 3 | Batch_idx: 590 |  Loss: (0.9713) | Acc: (65.42%) (24745/37824)
# Epoch: 3 | Batch_idx: 600 |  Loss: (0.9708) | Acc: (65.46%) (25180/38464)
# Epoch: 3 | Batch_idx: 610 |  Loss: (0.9708) | Acc: (65.45%) (25593/39104)
# Epoch: 3 | Batch_idx: 620 |  Loss: (0.9692) | Acc: (65.50%) (26033/39744)
# Epoch: 3 | Batch_idx: 630 |  Loss: (0.9676) | Acc: (65.59%) (26486/40384)
# Epoch: 3 | Batch_idx: 640 |  Loss: (0.9667) | Acc: (65.61%) (26915/41024)
# Epoch: 3 | Batch_idx: 650 |  Loss: (0.9670) | Acc: (65.60%) (27332/41664)
# Epoch: 3 | Batch_idx: 660 |  Loss: (0.9659) | Acc: (65.65%) (27774/42304)
# Epoch: 3 | Batch_idx: 670 |  Loss: (0.9644) | Acc: (65.72%) (28223/42944)
# Epoch: 3 | Batch_idx: 680 |  Loss: (0.9643) | Acc: (65.77%) (28666/43584)
# Epoch: 3 | Batch_idx: 690 |  Loss: (0.9646) | Acc: (65.77%) (29084/44224)
# Epoch: 3 | Batch_idx: 700 |  Loss: (0.9635) | Acc: (65.79%) (29514/44864)
# Epoch: 3 | Batch_idx: 710 |  Loss: (0.9635) | Acc: (65.79%) (29935/45504)
# Epoch: 3 | Batch_idx: 720 |  Loss: (0.9630) | Acc: (65.80%) (30364/46144)
# Epoch: 3 | Batch_idx: 730 |  Loss: (0.9632) | Acc: (65.79%) (30781/46784)
# Epoch: 3 | Batch_idx: 740 |  Loss: (0.9623) | Acc: (65.82%) (31215/47424)
# Epoch: 3 | Batch_idx: 750 |  Loss: (0.9613) | Acc: (65.85%) (31648/48064)
# Epoch: 3 | Batch_idx: 760 |  Loss: (0.9610) | Acc: (65.87%) (32080/48704)
# Epoch: 3 | Batch_idx: 770 |  Loss: (0.9609) | Acc: (65.86%) (32499/49344)
# Epoch: 3 | Batch_idx: 780 |  Loss: (0.9598) | Acc: (65.90%) (32939/49984)
# => saving checkpoint
# # TEST : Loss: (0.9844) | Acc: (65.63%) (6563/10000)
# Epoch: 4 | Batch_idx: 0 |  Loss: (1.0485) | Acc: (57.81%) (37/64)
# Epoch: 4 | Batch_idx: 10 |  Loss: (0.9703) | Acc: (63.21%) (445/704)
# Epoch: 4 | Batch_idx: 20 |  Loss: (0.9157) | Acc: (67.11%) (902/1344)
# Epoch: 4 | Batch_idx: 30 |  Loss: (0.9101) | Acc: (68.35%) (1356/1984)
# Epoch: 4 | Batch_idx: 40 |  Loss: (0.9036) | Acc: (68.22%) (1790/2624)
# Epoch: 4 | Batch_idx: 50 |  Loss: (0.8969) | Acc: (68.41%) (2233/3264)
# Epoch: 4 | Batch_idx: 60 |  Loss: (0.8946) | Acc: (68.34%) (2668/3904)
# Epoch: 4 | Batch_idx: 70 |  Loss: (0.8843) | Acc: (68.49%) (3112/4544)
# Epoch: 4 | Batch_idx: 80 |  Loss: (0.8716) | Acc: (69.06%) (3580/5184)
# Epoch: 4 | Batch_idx: 90 |  Loss: (0.8708) | Acc: (69.33%) (4038/5824)
# Epoch: 4 | Batch_idx: 100 |  Loss: (0.8615) | Acc: (69.63%) (4501/6464)
# Epoch: 4 | Batch_idx: 110 |  Loss: (0.8552) | Acc: (69.64%) (4947/7104)
# Epoch: 4 | Batch_idx: 120 |  Loss: (0.8542) | Acc: (69.72%) (5399/7744)
# Epoch: 4 | Batch_idx: 130 |  Loss: (0.8505) | Acc: (69.97%) (5866/8384)
# Epoch: 4 | Batch_idx: 140 |  Loss: (0.8510) | Acc: (69.92%) (6310/9024)
# Epoch: 4 | Batch_idx: 150 |  Loss: (0.8547) | Acc: (69.75%) (6741/9664)
# Epoch: 4 | Batch_idx: 160 |  Loss: (0.8588) | Acc: (69.65%) (7177/10304)
# Epoch: 4 | Batch_idx: 170 |  Loss: (0.8558) | Acc: (69.76%) (7634/10944)
# Epoch: 4 | Batch_idx: 180 |  Loss: (0.8584) | Acc: (69.65%) (8068/11584)
# Epoch: 4 | Batch_idx: 190 |  Loss: (0.8598) | Acc: (69.53%) (8499/12224)
# Epoch: 4 | Batch_idx: 200 |  Loss: (0.8612) | Acc: (69.46%) (8935/12864)
# Epoch: 4 | Batch_idx: 210 |  Loss: (0.8614) | Acc: (69.47%) (9381/13504)
# Epoch: 4 | Batch_idx: 220 |  Loss: (0.8635) | Acc: (69.32%) (9804/14144)
# Epoch: 4 | Batch_idx: 230 |  Loss: (0.8646) | Acc: (69.31%) (10247/14784)
# Epoch: 4 | Batch_idx: 240 |  Loss: (0.8644) | Acc: (69.39%) (10703/15424)
# Epoch: 4 | Batch_idx: 250 |  Loss: (0.8636) | Acc: (69.43%) (11153/16064)
# Epoch: 4 | Batch_idx: 260 |  Loss: (0.8661) | Acc: (69.31%) (11578/16704)
# Epoch: 4 | Batch_idx: 270 |  Loss: (0.8676) | Acc: (69.27%) (12015/17344)
# Epoch: 4 | Batch_idx: 280 |  Loss: (0.8667) | Acc: (69.32%) (12466/17984)
# Epoch: 4 | Batch_idx: 290 |  Loss: (0.8690) | Acc: (69.23%) (12893/18624)
# Epoch: 4 | Batch_idx: 300 |  Loss: (0.8685) | Acc: (69.23%) (13336/19264)
# Epoch: 4 | Batch_idx: 310 |  Loss: (0.8653) | Acc: (69.33%) (13800/19904)
# Epoch: 4 | Batch_idx: 320 |  Loss: (0.8636) | Acc: (69.46%) (14269/20544)
# Epoch: 4 | Batch_idx: 330 |  Loss: (0.8623) | Acc: (69.49%) (14721/21184)
# Epoch: 4 | Batch_idx: 340 |  Loss: (0.8627) | Acc: (69.53%) (15174/21824)
# Epoch: 4 | Batch_idx: 350 |  Loss: (0.8651) | Acc: (69.52%) (15616/22464)
# Epoch: 4 | Batch_idx: 360 |  Loss: (0.8648) | Acc: (69.53%) (16065/23104)
# Epoch: 4 | Batch_idx: 370 |  Loss: (0.8620) | Acc: (69.57%) (16518/23744)
# Epoch: 4 | Batch_idx: 380 |  Loss: (0.8612) | Acc: (69.58%) (16966/24384)
# Epoch: 4 | Batch_idx: 390 |  Loss: (0.8601) | Acc: (69.65%) (17429/25024)
# Epoch: 4 | Batch_idx: 400 |  Loss: (0.8608) | Acc: (69.64%) (17873/25664)
# Epoch: 4 | Batch_idx: 410 |  Loss: (0.8580) | Acc: (69.73%) (18341/26304)
# Epoch: 4 | Batch_idx: 420 |  Loss: (0.8582) | Acc: (69.77%) (18798/26944)
# Epoch: 4 | Batch_idx: 430 |  Loss: (0.8578) | Acc: (69.74%) (19238/27584)
# Epoch: 4 | Batch_idx: 440 |  Loss: (0.8584) | Acc: (69.67%) (19663/28224)
# Epoch: 4 | Batch_idx: 450 |  Loss: (0.8590) | Acc: (69.62%) (20094/28864)
# Epoch: 4 | Batch_idx: 460 |  Loss: (0.8610) | Acc: (69.55%) (20520/29504)
# Epoch: 4 | Batch_idx: 470 |  Loss: (0.8614) | Acc: (69.54%) (20963/30144)
# Epoch: 4 | Batch_idx: 480 |  Loss: (0.8613) | Acc: (69.58%) (21418/30784)
# Epoch: 4 | Batch_idx: 490 |  Loss: (0.8599) | Acc: (69.65%) (21888/31424)
# Epoch: 4 | Batch_idx: 500 |  Loss: (0.8599) | Acc: (69.66%) (22337/32064)
# Epoch: 4 | Batch_idx: 510 |  Loss: (0.8611) | Acc: (69.62%) (22767/32704)
# Epoch: 4 | Batch_idx: 520 |  Loss: (0.8594) | Acc: (69.69%) (23238/33344)
# Epoch: 4 | Batch_idx: 530 |  Loss: (0.8592) | Acc: (69.69%) (23683/33984)
# Epoch: 4 | Batch_idx: 540 |  Loss: (0.8575) | Acc: (69.76%) (24152/34624)
# Epoch: 4 | Batch_idx: 550 |  Loss: (0.8579) | Acc: (69.73%) (24591/35264)
# Epoch: 4 | Batch_idx: 560 |  Loss: (0.8580) | Acc: (69.71%) (25028/35904)
# Epoch: 4 | Batch_idx: 570 |  Loss: (0.8579) | Acc: (69.69%) (25467/36544)
# Epoch: 4 | Batch_idx: 580 |  Loss: (0.8574) | Acc: (69.74%) (25933/37184)
# Epoch: 4 | Batch_idx: 590 |  Loss: (0.8568) | Acc: (69.75%) (26381/37824)
# Epoch: 4 | Batch_idx: 600 |  Loss: (0.8560) | Acc: (69.77%) (26838/38464)
# Epoch: 4 | Batch_idx: 610 |  Loss: (0.8568) | Acc: (69.76%) (27280/39104)
# Epoch: 4 | Batch_idx: 620 |  Loss: (0.8567) | Acc: (69.76%) (27725/39744)
# Epoch: 4 | Batch_idx: 630 |  Loss: (0.8554) | Acc: (69.80%) (28190/40384)
# Epoch: 4 | Batch_idx: 640 |  Loss: (0.8564) | Acc: (69.79%) (28631/41024)
# Epoch: 4 | Batch_idx: 650 |  Loss: (0.8558) | Acc: (69.81%) (29086/41664)
# Epoch: 4 | Batch_idx: 660 |  Loss: (0.8557) | Acc: (69.84%) (29545/42304)
# Epoch: 4 | Batch_idx: 670 |  Loss: (0.8554) | Acc: (69.84%) (29993/42944)
# Epoch: 4 | Batch_idx: 680 |  Loss: (0.8558) | Acc: (69.81%) (30426/43584)
# Epoch: 4 | Batch_idx: 690 |  Loss: (0.8552) | Acc: (69.84%) (30887/44224)
# Epoch: 4 | Batch_idx: 700 |  Loss: (0.8540) | Acc: (69.89%) (31354/44864)
# Epoch: 4 | Batch_idx: 710 |  Loss: (0.8530) | Acc: (69.89%) (31802/45504)
# Epoch: 4 | Batch_idx: 720 |  Loss: (0.8521) | Acc: (69.91%) (32258/46144)
# Epoch: 4 | Batch_idx: 730 |  Loss: (0.8517) | Acc: (69.92%) (32711/46784)
# Epoch: 4 | Batch_idx: 740 |  Loss: (0.8513) | Acc: (69.94%) (33168/47424)
# Epoch: 4 | Batch_idx: 750 |  Loss: (0.8515) | Acc: (69.91%) (33600/48064)
# Epoch: 4 | Batch_idx: 760 |  Loss: (0.8511) | Acc: (69.92%) (34053/48704)
# Epoch: 4 | Batch_idx: 770 |  Loss: (0.8493) | Acc: (70.00%) (34542/49344)
# Epoch: 4 | Batch_idx: 780 |  Loss: (0.8487) | Acc: (70.03%) (35005/49984)
# => saving checkpoint
# # TEST : Loss: (0.8130) | Acc: (72.01%) (7201/10000)
# Epoch: 5 | Batch_idx: 0 |  Loss: (0.9717) | Acc: (67.19%) (43/64)
# Epoch: 5 | Batch_idx: 10 |  Loss: (0.7693) | Acc: (74.15%) (522/704)
# Epoch: 5 | Batch_idx: 20 |  Loss: (0.7537) | Acc: (74.33%) (999/1344)
# Epoch: 5 | Batch_idx: 30 |  Loss: (0.7518) | Acc: (74.19%) (1472/1984)
# Epoch: 5 | Batch_idx: 40 |  Loss: (0.7440) | Acc: (74.28%) (1949/2624)
# Epoch: 5 | Batch_idx: 50 |  Loss: (0.7599) | Acc: (73.41%) (2396/3264)
# Epoch: 5 | Batch_idx: 60 |  Loss: (0.7662) | Acc: (73.16%) (2856/3904)
# Epoch: 5 | Batch_idx: 70 |  Loss: (0.7699) | Acc: (73.02%) (3318/4544)
# Epoch: 5 | Batch_idx: 80 |  Loss: (0.7740) | Acc: (72.84%) (3776/5184)
# Epoch: 5 | Batch_idx: 90 |  Loss: (0.7751) | Acc: (72.84%) (4242/5824)
# Epoch: 5 | Batch_idx: 100 |  Loss: (0.7766) | Acc: (72.79%) (4705/6464)
# Epoch: 5 | Batch_idx: 110 |  Loss: (0.7744) | Acc: (72.97%) (5184/7104)
# Epoch: 5 | Batch_idx: 120 |  Loss: (0.7779) | Acc: (72.90%) (5645/7744)
# Epoch: 5 | Batch_idx: 130 |  Loss: (0.7800) | Acc: (72.77%) (6101/8384)
# Epoch: 5 | Batch_idx: 140 |  Loss: (0.7792) | Acc: (72.81%) (6570/9024)
# Epoch: 5 | Batch_idx: 150 |  Loss: (0.7781) | Acc: (72.91%) (7046/9664)
# Epoch: 5 | Batch_idx: 160 |  Loss: (0.7788) | Acc: (72.90%) (7512/10304)
# Epoch: 5 | Batch_idx: 170 |  Loss: (0.7799) | Acc: (72.87%) (7975/10944)
# Epoch: 5 | Batch_idx: 180 |  Loss: (0.7798) | Acc: (72.82%) (8435/11584)
# Epoch: 5 | Batch_idx: 190 |  Loss: (0.7804) | Acc: (72.79%) (8898/12224)
# Epoch: 5 | Batch_idx: 200 |  Loss: (0.7831) | Acc: (72.73%) (9356/12864)
# Epoch: 5 | Batch_idx: 210 |  Loss: (0.7822) | Acc: (72.80%) (9831/13504)
# Epoch: 5 | Batch_idx: 220 |  Loss: (0.7814) | Acc: (72.77%) (10292/14144)
# Epoch: 5 | Batch_idx: 230 |  Loss: (0.7807) | Acc: (72.75%) (10755/14784)
# Epoch: 5 | Batch_idx: 240 |  Loss: (0.7803) | Acc: (72.78%) (11226/15424)
# Epoch: 5 | Batch_idx: 250 |  Loss: (0.7789) | Acc: (72.84%) (11701/16064)
# Epoch: 5 | Batch_idx: 260 |  Loss: (0.7792) | Acc: (72.77%) (12155/16704)
# Epoch: 5 | Batch_idx: 270 |  Loss: (0.7772) | Acc: (72.87%) (12638/17344)
# Epoch: 5 | Batch_idx: 280 |  Loss: (0.7774) | Acc: (72.84%) (13100/17984)
# Epoch: 5 | Batch_idx: 290 |  Loss: (0.7781) | Acc: (72.86%) (13569/18624)
# Epoch: 5 | Batch_idx: 300 |  Loss: (0.7765) | Acc: (72.89%) (14041/19264)
# Epoch: 5 | Batch_idx: 310 |  Loss: (0.7767) | Acc: (72.93%) (14515/19904)
# Epoch: 5 | Batch_idx: 320 |  Loss: (0.7773) | Acc: (72.88%) (14972/20544)
# Epoch: 5 | Batch_idx: 330 |  Loss: (0.7752) | Acc: (72.93%) (15450/21184)
# Epoch: 5 | Batch_idx: 340 |  Loss: (0.7755) | Acc: (72.92%) (15915/21824)
# Epoch: 5 | Batch_idx: 350 |  Loss: (0.7740) | Acc: (72.94%) (16386/22464)
# Epoch: 5 | Batch_idx: 360 |  Loss: (0.7737) | Acc: (72.96%) (16857/23104)
# Epoch: 5 | Batch_idx: 370 |  Loss: (0.7728) | Acc: (73.00%) (17333/23744)
# Epoch: 5 | Batch_idx: 380 |  Loss: (0.7710) | Acc: (73.04%) (17809/24384)
# Epoch: 5 | Batch_idx: 390 |  Loss: (0.7690) | Acc: (73.11%) (18296/25024)
# Epoch: 5 | Batch_idx: 400 |  Loss: (0.7693) | Acc: (73.08%) (18755/25664)
# Epoch: 5 | Batch_idx: 410 |  Loss: (0.7680) | Acc: (73.11%) (19232/26304)
# Epoch: 5 | Batch_idx: 420 |  Loss: (0.7713) | Acc: (73.02%) (19674/26944)
# Epoch: 5 | Batch_idx: 430 |  Loss: (0.7719) | Acc: (72.98%) (20131/27584)
# Epoch: 5 | Batch_idx: 440 |  Loss: (0.7728) | Acc: (72.95%) (20590/28224)
# Epoch: 5 | Batch_idx: 450 |  Loss: (0.7736) | Acc: (72.91%) (21044/28864)
# Epoch: 5 | Batch_idx: 460 |  Loss: (0.7732) | Acc: (72.93%) (21517/29504)
# Epoch: 5 | Batch_idx: 470 |  Loss: (0.7751) | Acc: (72.90%) (21975/30144)
# Epoch: 5 | Batch_idx: 480 |  Loss: (0.7758) | Acc: (72.82%) (22416/30784)
# Epoch: 5 | Batch_idx: 490 |  Loss: (0.7766) | Acc: (72.82%) (22883/31424)
# Epoch: 5 | Batch_idx: 500 |  Loss: (0.7748) | Acc: (72.89%) (23372/32064)
# Epoch: 5 | Batch_idx: 510 |  Loss: (0.7742) | Acc: (72.91%) (23846/32704)
# Epoch: 5 | Batch_idx: 520 |  Loss: (0.7734) | Acc: (72.92%) (24313/33344)
# Epoch: 5 | Batch_idx: 530 |  Loss: (0.7730) | Acc: (72.94%) (24787/33984)
# Epoch: 5 | Batch_idx: 540 |  Loss: (0.7751) | Acc: (72.84%) (25221/34624)
# Epoch: 5 | Batch_idx: 550 |  Loss: (0.7756) | Acc: (72.84%) (25687/35264)
# Epoch: 5 | Batch_idx: 560 |  Loss: (0.7746) | Acc: (72.89%) (26170/35904)
# Epoch: 5 | Batch_idx: 570 |  Loss: (0.7740) | Acc: (72.89%) (26638/36544)
# Epoch: 5 | Batch_idx: 580 |  Loss: (0.7740) | Acc: (72.87%) (27097/37184)
# Epoch: 5 | Batch_idx: 590 |  Loss: (0.7731) | Acc: (72.92%) (27581/37824)
# Epoch: 5 | Batch_idx: 600 |  Loss: (0.7730) | Acc: (72.91%) (28044/38464)
# Epoch: 5 | Batch_idx: 610 |  Loss: (0.7720) | Acc: (72.95%) (28525/39104)
# Epoch: 5 | Batch_idx: 620 |  Loss: (0.7719) | Acc: (72.96%) (28996/39744)
# Epoch: 5 | Batch_idx: 630 |  Loss: (0.7712) | Acc: (72.98%) (29471/40384)
# Epoch: 5 | Batch_idx: 640 |  Loss: (0.7702) | Acc: (72.99%) (29945/41024)
# Epoch: 5 | Batch_idx: 650 |  Loss: (0.7699) | Acc: (73.00%) (30413/41664)
# Epoch: 5 | Batch_idx: 660 |  Loss: (0.7684) | Acc: (73.08%) (30914/42304)
# Epoch: 5 | Batch_idx: 670 |  Loss: (0.7672) | Acc: (73.14%) (31408/42944)
# Epoch: 5 | Batch_idx: 680 |  Loss: (0.7671) | Acc: (73.16%) (31887/43584)
# Epoch: 5 | Batch_idx: 690 |  Loss: (0.7658) | Acc: (73.20%) (32372/44224)
# Epoch: 5 | Batch_idx: 700 |  Loss: (0.7659) | Acc: (73.20%) (32839/44864)
# Epoch: 5 | Batch_idx: 710 |  Loss: (0.7656) | Acc: (73.23%) (33323/45504)
# Epoch: 5 | Batch_idx: 720 |  Loss: (0.7642) | Acc: (73.29%) (33819/46144)
# Epoch: 5 | Batch_idx: 730 |  Loss: (0.7637) | Acc: (73.29%) (34287/46784)
# Epoch: 5 | Batch_idx: 740 |  Loss: (0.7629) | Acc: (73.30%) (34764/47424)
# Epoch: 5 | Batch_idx: 750 |  Loss: (0.7615) | Acc: (73.35%) (35256/48064)
# Epoch: 5 | Batch_idx: 760 |  Loss: (0.7610) | Acc: (73.38%) (35739/48704)
# Epoch: 5 | Batch_idx: 770 |  Loss: (0.7601) | Acc: (73.42%) (36228/49344)
# Epoch: 5 | Batch_idx: 780 |  Loss: (0.7593) | Acc: (73.45%) (36715/49984)
# => saving checkpoint
# # TEST : Loss: (0.8310) | Acc: (72.38%) (7238/10000)
# Epoch: 6 | Batch_idx: 0 |  Loss: (0.6008) | Acc: (78.12%) (50/64)
# Epoch: 6 | Batch_idx: 10 |  Loss: (0.6872) | Acc: (74.43%) (524/704)
# Epoch: 6 | Batch_idx: 20 |  Loss: (0.6920) | Acc: (75.22%) (1011/1344)
# Epoch: 6 | Batch_idx: 30 |  Loss: (0.7065) | Acc: (75.20%) (1492/1984)
# Epoch: 6 | Batch_idx: 40 |  Loss: (0.7257) | Acc: (74.24%) (1948/2624)
# Epoch: 6 | Batch_idx: 50 |  Loss: (0.7277) | Acc: (74.36%) (2427/3264)
# Epoch: 6 | Batch_idx: 60 |  Loss: (0.7103) | Acc: (74.95%) (2926/3904)
# Epoch: 6 | Batch_idx: 70 |  Loss: (0.7127) | Acc: (74.98%) (3407/4544)
# Epoch: 6 | Batch_idx: 80 |  Loss: (0.7134) | Acc: (74.86%) (3881/5184)
# Epoch: 6 | Batch_idx: 90 |  Loss: (0.7059) | Acc: (75.03%) (4370/5824)
# Epoch: 6 | Batch_idx: 100 |  Loss: (0.7134) | Acc: (74.77%) (4833/6464)
# Epoch: 6 | Batch_idx: 110 |  Loss: (0.7164) | Acc: (74.62%) (5301/7104)
# Epoch: 6 | Batch_idx: 120 |  Loss: (0.7109) | Acc: (74.82%) (5794/7744)
# Epoch: 6 | Batch_idx: 130 |  Loss: (0.7012) | Acc: (75.26%) (6310/8384)
# Epoch: 6 | Batch_idx: 140 |  Loss: (0.6997) | Acc: (75.23%) (6789/9024)
# Epoch: 6 | Batch_idx: 150 |  Loss: (0.7031) | Acc: (75.10%) (7258/9664)
# Epoch: 6 | Batch_idx: 160 |  Loss: (0.7082) | Acc: (74.98%) (7726/10304)
# Epoch: 6 | Batch_idx: 170 |  Loss: (0.7077) | Acc: (75.10%) (8219/10944)
# Epoch: 6 | Batch_idx: 180 |  Loss: (0.7051) | Acc: (75.21%) (8712/11584)
# Epoch: 6 | Batch_idx: 190 |  Loss: (0.7053) | Acc: (75.19%) (9191/12224)
# Epoch: 6 | Batch_idx: 200 |  Loss: (0.7087) | Acc: (75.13%) (9665/12864)
# Epoch: 6 | Batch_idx: 210 |  Loss: (0.7109) | Acc: (75.03%) (10132/13504)
# Epoch: 6 | Batch_idx: 220 |  Loss: (0.7119) | Acc: (74.99%) (10607/14144)
# Epoch: 6 | Batch_idx: 230 |  Loss: (0.7119) | Acc: (75.00%) (11088/14784)
# Epoch: 6 | Batch_idx: 240 |  Loss: (0.7133) | Acc: (74.99%) (11566/15424)
# Epoch: 6 | Batch_idx: 250 |  Loss: (0.7121) | Acc: (75.05%) (12056/16064)
# Epoch: 6 | Batch_idx: 260 |  Loss: (0.7126) | Acc: (75.03%) (12533/16704)
# Epoch: 6 | Batch_idx: 270 |  Loss: (0.7142) | Acc: (75.07%) (13020/17344)
# Epoch: 6 | Batch_idx: 280 |  Loss: (0.7118) | Acc: (75.16%) (13517/17984)
# Epoch: 6 | Batch_idx: 290 |  Loss: (0.7109) | Acc: (75.17%) (14000/18624)
# Epoch: 6 | Batch_idx: 300 |  Loss: (0.7091) | Acc: (75.26%) (14498/19264)
# Epoch: 6 | Batch_idx: 310 |  Loss: (0.7062) | Acc: (75.33%) (14993/19904)
# Epoch: 6 | Batch_idx: 320 |  Loss: (0.7051) | Acc: (75.36%) (15482/20544)
# Epoch: 6 | Batch_idx: 330 |  Loss: (0.7043) | Acc: (75.41%) (15975/21184)
# Epoch: 6 | Batch_idx: 340 |  Loss: (0.7039) | Acc: (75.45%) (16467/21824)
# Epoch: 6 | Batch_idx: 350 |  Loss: (0.7031) | Acc: (75.50%) (16960/22464)
# Epoch: 6 | Batch_idx: 360 |  Loss: (0.7052) | Acc: (75.47%) (17437/23104)
# Epoch: 6 | Batch_idx: 370 |  Loss: (0.7056) | Acc: (75.40%) (17902/23744)
# Epoch: 6 | Batch_idx: 380 |  Loss: (0.7041) | Acc: (75.42%) (18390/24384)
# Epoch: 6 | Batch_idx: 390 |  Loss: (0.7048) | Acc: (75.40%) (18868/25024)
# Epoch: 6 | Batch_idx: 400 |  Loss: (0.7036) | Acc: (75.47%) (19368/25664)
# Epoch: 6 | Batch_idx: 410 |  Loss: (0.7015) | Acc: (75.59%) (19883/26304)
# Epoch: 6 | Batch_idx: 420 |  Loss: (0.7009) | Acc: (75.63%) (20377/26944)
# Epoch: 6 | Batch_idx: 430 |  Loss: (0.7000) | Acc: (75.70%) (20880/27584)
# Epoch: 6 | Batch_idx: 440 |  Loss: (0.6985) | Acc: (75.73%) (21375/28224)
# Epoch: 6 | Batch_idx: 450 |  Loss: (0.6994) | Acc: (75.72%) (21857/28864)
# Epoch: 6 | Batch_idx: 460 |  Loss: (0.6982) | Acc: (75.76%) (22351/29504)
# Epoch: 6 | Batch_idx: 470 |  Loss: (0.6961) | Acc: (75.83%) (22857/30144)
# Epoch: 6 | Batch_idx: 480 |  Loss: (0.6952) | Acc: (75.86%) (23352/30784)
# Epoch: 6 | Batch_idx: 490 |  Loss: (0.6936) | Acc: (75.89%) (23849/31424)
# Epoch: 6 | Batch_idx: 500 |  Loss: (0.6924) | Acc: (75.93%) (24346/32064)
# Epoch: 6 | Batch_idx: 510 |  Loss: (0.6922) | Acc: (75.93%) (24832/32704)
# Epoch: 6 | Batch_idx: 520 |  Loss: (0.6926) | Acc: (75.94%) (25322/33344)
# Epoch: 6 | Batch_idx: 530 |  Loss: (0.6922) | Acc: (75.97%) (25819/33984)
# Epoch: 6 | Batch_idx: 540 |  Loss: (0.6908) | Acc: (76.04%) (26327/34624)
# Epoch: 6 | Batch_idx: 550 |  Loss: (0.6911) | Acc: (76.02%) (26807/35264)
# Epoch: 6 | Batch_idx: 560 |  Loss: (0.6903) | Acc: (76.03%) (27297/35904)
# Epoch: 6 | Batch_idx: 570 |  Loss: (0.6894) | Acc: (76.06%) (27794/36544)
# Epoch: 6 | Batch_idx: 580 |  Loss: (0.6879) | Acc: (76.14%) (28311/37184)
# Epoch: 6 | Batch_idx: 590 |  Loss: (0.6878) | Acc: (76.18%) (28813/37824)
# Epoch: 6 | Batch_idx: 600 |  Loss: (0.6872) | Acc: (76.19%) (29306/38464)
# Epoch: 6 | Batch_idx: 610 |  Loss: (0.6860) | Acc: (76.25%) (29815/39104)
# Epoch: 6 | Batch_idx: 620 |  Loss: (0.6868) | Acc: (76.21%) (30288/39744)
# Epoch: 6 | Batch_idx: 630 |  Loss: (0.6860) | Acc: (76.22%) (30781/40384)
# Epoch: 6 | Batch_idx: 640 |  Loss: (0.6851) | Acc: (76.22%) (31269/41024)
# Epoch: 6 | Batch_idx: 650 |  Loss: (0.6846) | Acc: (76.21%) (31753/41664)
# Epoch: 6 | Batch_idx: 660 |  Loss: (0.6838) | Acc: (76.25%) (32255/42304)
# Epoch: 6 | Batch_idx: 670 |  Loss: (0.6847) | Acc: (76.23%) (32735/42944)
# Epoch: 6 | Batch_idx: 680 |  Loss: (0.6849) | Acc: (76.22%) (33221/43584)
# Epoch: 6 | Batch_idx: 690 |  Loss: (0.6863) | Acc: (76.16%) (33679/44224)
# Epoch: 6 | Batch_idx: 700 |  Loss: (0.6856) | Acc: (76.17%) (34171/44864)
# Epoch: 6 | Batch_idx: 710 |  Loss: (0.6857) | Acc: (76.16%) (34655/45504)
# Epoch: 6 | Batch_idx: 720 |  Loss: (0.6851) | Acc: (76.20%) (35161/46144)
# Epoch: 6 | Batch_idx: 730 |  Loss: (0.6851) | Acc: (76.21%) (35656/46784)
# Epoch: 6 | Batch_idx: 740 |  Loss: (0.6855) | Acc: (76.21%) (36143/47424)
# Epoch: 6 | Batch_idx: 750 |  Loss: (0.6835) | Acc: (76.28%) (36665/48064)
# Epoch: 6 | Batch_idx: 760 |  Loss: (0.6834) | Acc: (76.30%) (37162/48704)
# Epoch: 6 | Batch_idx: 770 |  Loss: (0.6828) | Acc: (76.30%) (37648/49344)
# Epoch: 6 | Batch_idx: 780 |  Loss: (0.6825) | Acc: (76.32%) (38146/49984)
# => saving checkpoint
# # TEST : Loss: (0.7334) | Acc: (75.15%) (7515/10000)
# Epoch: 7 | Batch_idx: 0 |  Loss: (0.8945) | Acc: (68.75%) (44/64)
# Epoch: 7 | Batch_idx: 10 |  Loss: (0.6590) | Acc: (76.42%) (538/704)
# Epoch: 7 | Batch_idx: 20 |  Loss: (0.6670) | Acc: (75.89%) (1020/1344)
# Epoch: 7 | Batch_idx: 30 |  Loss: (0.6338) | Acc: (77.57%) (1539/1984)
# Epoch: 7 | Batch_idx: 40 |  Loss: (0.6187) | Acc: (78.20%) (2052/2624)
# Epoch: 7 | Batch_idx: 50 |  Loss: (0.6151) | Acc: (78.19%) (2552/3264)
# Epoch: 7 | Batch_idx: 60 |  Loss: (0.6108) | Acc: (78.07%) (3048/3904)
# Epoch: 7 | Batch_idx: 70 |  Loss: (0.6089) | Acc: (78.28%) (3557/4544)
# Epoch: 7 | Batch_idx: 80 |  Loss: (0.6120) | Acc: (78.28%) (4058/5184)
# Epoch: 7 | Batch_idx: 90 |  Loss: (0.6170) | Acc: (78.21%) (4555/5824)
# Epoch: 7 | Batch_idx: 100 |  Loss: (0.6203) | Acc: (78.14%) (5051/6464)
# Epoch: 7 | Batch_idx: 110 |  Loss: (0.6166) | Acc: (78.08%) (5547/7104)
# Epoch: 7 | Batch_idx: 120 |  Loss: (0.6156) | Acc: (78.22%) (6057/7744)
# Epoch: 7 | Batch_idx: 130 |  Loss: (0.6142) | Acc: (78.45%) (6577/8384)
# Epoch: 7 | Batch_idx: 140 |  Loss: (0.6157) | Acc: (78.44%) (7078/9024)
# Epoch: 7 | Batch_idx: 150 |  Loss: (0.6110) | Acc: (78.49%) (7585/9664)
# Epoch: 7 | Batch_idx: 160 |  Loss: (0.6122) | Acc: (78.46%) (8085/10304)
# Epoch: 7 | Batch_idx: 170 |  Loss: (0.6119) | Acc: (78.41%) (8581/10944)
# Epoch: 7 | Batch_idx: 180 |  Loss: (0.6122) | Acc: (78.44%) (9087/11584)
# Epoch: 7 | Batch_idx: 190 |  Loss: (0.6123) | Acc: (78.47%) (9592/12224)
# Epoch: 7 | Batch_idx: 200 |  Loss: (0.6144) | Acc: (78.42%) (10088/12864)
# Epoch: 7 | Batch_idx: 210 |  Loss: (0.6164) | Acc: (78.41%) (10588/13504)
# Epoch: 7 | Batch_idx: 220 |  Loss: (0.6194) | Acc: (78.30%) (11075/14144)
# Epoch: 7 | Batch_idx: 230 |  Loss: (0.6188) | Acc: (78.35%) (11584/14784)
# Epoch: 7 | Batch_idx: 240 |  Loss: (0.6198) | Acc: (78.32%) (12080/15424)
# Epoch: 7 | Batch_idx: 250 |  Loss: (0.6216) | Acc: (78.27%) (12574/16064)
# Epoch: 7 | Batch_idx: 260 |  Loss: (0.6197) | Acc: (78.32%) (13082/16704)
# Epoch: 7 | Batch_idx: 270 |  Loss: (0.6206) | Acc: (78.32%) (13584/17344)
# Epoch: 7 | Batch_idx: 280 |  Loss: (0.6184) | Acc: (78.38%) (14096/17984)
# Epoch: 7 | Batch_idx: 290 |  Loss: (0.6181) | Acc: (78.39%) (14600/18624)
# Epoch: 7 | Batch_idx: 300 |  Loss: (0.6190) | Acc: (78.34%) (15092/19264)
# Epoch: 7 | Batch_idx: 310 |  Loss: (0.6181) | Acc: (78.33%) (15591/19904)
# Epoch: 7 | Batch_idx: 320 |  Loss: (0.6191) | Acc: (78.27%) (16079/20544)
# Epoch: 7 | Batch_idx: 330 |  Loss: (0.6180) | Acc: (78.29%) (16584/21184)
# Epoch: 7 | Batch_idx: 340 |  Loss: (0.6187) | Acc: (78.36%) (17101/21824)
# Epoch: 7 | Batch_idx: 350 |  Loss: (0.6191) | Acc: (78.33%) (17597/22464)
# Epoch: 7 | Batch_idx: 360 |  Loss: (0.6197) | Acc: (78.29%) (18088/23104)
# Epoch: 7 | Batch_idx: 370 |  Loss: (0.6187) | Acc: (78.30%) (18592/23744)
# Epoch: 7 | Batch_idx: 380 |  Loss: (0.6199) | Acc: (78.27%) (19085/24384)
# Epoch: 7 | Batch_idx: 390 |  Loss: (0.6195) | Acc: (78.30%) (19594/25024)
# Epoch: 7 | Batch_idx: 400 |  Loss: (0.6209) | Acc: (78.25%) (20081/25664)
# Epoch: 7 | Batch_idx: 410 |  Loss: (0.6207) | Acc: (78.24%) (20581/26304)
# Epoch: 7 | Batch_idx: 420 |  Loss: (0.6204) | Acc: (78.24%) (21082/26944)
# Epoch: 7 | Batch_idx: 430 |  Loss: (0.6204) | Acc: (78.24%) (21583/27584)
# Epoch: 7 | Batch_idx: 440 |  Loss: (0.6209) | Acc: (78.23%) (22079/28224)
# Epoch: 7 | Batch_idx: 450 |  Loss: (0.6206) | Acc: (78.21%) (22575/28864)
# Epoch: 7 | Batch_idx: 460 |  Loss: (0.6207) | Acc: (78.21%) (23076/29504)
# Epoch: 7 | Batch_idx: 470 |  Loss: (0.6208) | Acc: (78.22%) (23580/30144)
# Epoch: 7 | Batch_idx: 480 |  Loss: (0.6205) | Acc: (78.23%) (24082/30784)
# Epoch: 7 | Batch_idx: 490 |  Loss: (0.6214) | Acc: (78.20%) (24575/31424)
# Epoch: 7 | Batch_idx: 500 |  Loss: (0.6225) | Acc: (78.18%) (25069/32064)
# Epoch: 7 | Batch_idx: 510 |  Loss: (0.6221) | Acc: (78.21%) (25578/32704)
# Epoch: 7 | Batch_idx: 520 |  Loss: (0.6208) | Acc: (78.25%) (26091/33344)
# Epoch: 7 | Batch_idx: 530 |  Loss: (0.6216) | Acc: (78.22%) (26582/33984)
# Epoch: 7 | Batch_idx: 540 |  Loss: (0.6218) | Acc: (78.21%) (27081/34624)
# Epoch: 7 | Batch_idx: 550 |  Loss: (0.6223) | Acc: (78.20%) (27575/35264)
# Epoch: 7 | Batch_idx: 560 |  Loss: (0.6216) | Acc: (78.21%) (28081/35904)
# Epoch: 7 | Batch_idx: 570 |  Loss: (0.6218) | Acc: (78.21%) (28580/36544)
# Epoch: 7 | Batch_idx: 580 |  Loss: (0.6218) | Acc: (78.22%) (29084/37184)
# Epoch: 7 | Batch_idx: 590 |  Loss: (0.6209) | Acc: (78.27%) (29603/37824)
# Epoch: 7 | Batch_idx: 600 |  Loss: (0.6206) | Acc: (78.27%) (30104/38464)
# Epoch: 7 | Batch_idx: 610 |  Loss: (0.6209) | Acc: (78.30%) (30617/39104)
# Epoch: 7 | Batch_idx: 620 |  Loss: (0.6203) | Acc: (78.32%) (31128/39744)
# Epoch: 7 | Batch_idx: 630 |  Loss: (0.6206) | Acc: (78.32%) (31629/40384)
# Epoch: 7 | Batch_idx: 640 |  Loss: (0.6199) | Acc: (78.34%) (32139/41024)
# Epoch: 7 | Batch_idx: 650 |  Loss: (0.6187) | Acc: (78.37%) (32654/41664)
# Epoch: 7 | Batch_idx: 660 |  Loss: (0.6189) | Acc: (78.37%) (33153/42304)
# Epoch: 7 | Batch_idx: 670 |  Loss: (0.6189) | Acc: (78.37%) (33654/42944)
# Epoch: 7 | Batch_idx: 680 |  Loss: (0.6182) | Acc: (78.40%) (34168/43584)
# Epoch: 7 | Batch_idx: 690 |  Loss: (0.6186) | Acc: (78.39%) (34665/44224)
# Epoch: 7 | Batch_idx: 700 |  Loss: (0.6178) | Acc: (78.41%) (35180/44864)
# Epoch: 7 | Batch_idx: 710 |  Loss: (0.6178) | Acc: (78.43%) (35687/45504)
# Epoch: 7 | Batch_idx: 720 |  Loss: (0.6178) | Acc: (78.44%) (36194/46144)
# Epoch: 7 | Batch_idx: 730 |  Loss: (0.6178) | Acc: (78.44%) (36698/46784)
# Epoch: 7 | Batch_idx: 740 |  Loss: (0.6175) | Acc: (78.45%) (37205/47424)
# Epoch: 7 | Batch_idx: 750 |  Loss: (0.6170) | Acc: (78.45%) (37708/48064)
# Epoch: 7 | Batch_idx: 760 |  Loss: (0.6161) | Acc: (78.51%) (38238/48704)
# Epoch: 7 | Batch_idx: 770 |  Loss: (0.6154) | Acc: (78.53%) (38748/49344)
# Epoch: 7 | Batch_idx: 780 |  Loss: (0.6148) | Acc: (78.54%) (39255/49984)
# => saving checkpoint
# # TEST : Loss: (0.7321) | Acc: (74.97%) (7497/10000)
# Epoch: 8 | Batch_idx: 0 |  Loss: (0.4812) | Acc: (85.94%) (55/64)
# Epoch: 8 | Batch_idx: 10 |  Loss: (0.6414) | Acc: (76.42%) (538/704)
# Epoch: 8 | Batch_idx: 20 |  Loss: (0.6841) | Acc: (76.04%) (1022/1344)
# Epoch: 8 | Batch_idx: 30 |  Loss: (0.6527) | Acc: (76.97%) (1527/1984)
# Epoch: 8 | Batch_idx: 40 |  Loss: (0.6282) | Acc: (77.97%) (2046/2624)
# Epoch: 8 | Batch_idx: 50 |  Loss: (0.6245) | Acc: (78.52%) (2563/3264)
# Epoch: 8 | Batch_idx: 60 |  Loss: (0.6158) | Acc: (79.02%) (3085/3904)
# Epoch: 8 | Batch_idx: 70 |  Loss: (0.6118) | Acc: (78.87%) (3584/4544)
# Epoch: 8 | Batch_idx: 80 |  Loss: (0.6023) | Acc: (78.94%) (4092/5184)
# Epoch: 8 | Batch_idx: 90 |  Loss: (0.6005) | Acc: (79.04%) (4603/5824)
# Epoch: 8 | Batch_idx: 100 |  Loss: (0.5966) | Acc: (79.12%) (5114/6464)
# Epoch: 8 | Batch_idx: 110 |  Loss: (0.5939) | Acc: (79.10%) (5619/7104)
# Epoch: 8 | Batch_idx: 120 |  Loss: (0.5938) | Acc: (79.34%) (6144/7744)
# Epoch: 8 | Batch_idx: 130 |  Loss: (0.5910) | Acc: (79.40%) (6657/8384)
# Epoch: 8 | Batch_idx: 140 |  Loss: (0.5876) | Acc: (79.44%) (7169/9024)
# Epoch: 8 | Batch_idx: 150 |  Loss: (0.5854) | Acc: (79.45%) (7678/9664)
# ...
# Epoch: 162 | Batch_idx: 290 |  Loss: (0.0081) | Acc: (99.86%) (18598/18624)
# Epoch: 162 | Batch_idx: 300 |  Loss: (0.0082) | Acc: (99.86%) (19237/19264)
# Epoch: 162 | Batch_idx: 310 |  Loss: (0.0081) | Acc: (99.86%) (19877/19904)
# Epoch: 162 | Batch_idx: 320 |  Loss: (0.0081) | Acc: (99.86%) (20516/20544)
# Epoch: 162 | Batch_idx: 330 |  Loss: (0.0081) | Acc: (99.86%) (21154/21184)
# Epoch: 162 | Batch_idx: 340 |  Loss: (0.0081) | Acc: (99.86%) (21793/21824)
# Epoch: 162 | Batch_idx: 350 |  Loss: (0.0080) | Acc: (99.86%) (22433/22464)
# Epoch: 162 | Batch_idx: 360 |  Loss: (0.0080) | Acc: (99.86%) (23072/23104)
# Epoch: 162 | Batch_idx: 370 |  Loss: (0.0080) | Acc: (99.86%) (23711/23744)
# Epoch: 162 | Batch_idx: 380 |  Loss: (0.0079) | Acc: (99.86%) (24351/24384)
# Epoch: 162 | Batch_idx: 390 |  Loss: (0.0081) | Acc: (99.86%) (24989/25024)
# Epoch: 162 | Batch_idx: 400 |  Loss: (0.0080) | Acc: (99.86%) (25629/25664)
# Epoch: 162 | Batch_idx: 410 |  Loss: (0.0080) | Acc: (99.86%) (26267/26304)
# Epoch: 162 | Batch_idx: 420 |  Loss: (0.0080) | Acc: (99.86%) (26907/26944)
# Epoch: 162 | Batch_idx: 430 |  Loss: (0.0080) | Acc: (99.87%) (27547/27584)
# Epoch: 162 | Batch_idx: 440 |  Loss: (0.0080) | Acc: (99.87%) (28187/28224)
# Epoch: 162 | Batch_idx: 450 |  Loss: (0.0079) | Acc: (99.87%) (28826/28864)
# Epoch: 162 | Batch_idx: 460 |  Loss: (0.0079) | Acc: (99.87%) (29466/29504)
# Epoch: 162 | Batch_idx: 470 |  Loss: (0.0079) | Acc: (99.87%) (30106/30144)
# Epoch: 162 | Batch_idx: 480 |  Loss: (0.0078) | Acc: (99.88%) (30746/30784)
# Epoch: 162 | Batch_idx: 490 |  Loss: (0.0078) | Acc: (99.88%) (31385/31424)
# Epoch: 162 | Batch_idx: 500 |  Loss: (0.0078) | Acc: (99.88%) (32024/32064)
# Epoch: 162 | Batch_idx: 510 |  Loss: (0.0077) | Acc: (99.88%) (32664/32704)
# Epoch: 162 | Batch_idx: 520 |  Loss: (0.0077) | Acc: (99.88%) (33303/33344)
# Epoch: 162 | Batch_idx: 530 |  Loss: (0.0077) | Acc: (99.88%) (33943/33984)
# Epoch: 162 | Batch_idx: 540 |  Loss: (0.0077) | Acc: (99.88%) (34582/34624)
# Epoch: 162 | Batch_idx: 550 |  Loss: (0.0076) | Acc: (99.88%) (35222/35264)
# Epoch: 162 | Batch_idx: 560 |  Loss: (0.0076) | Acc: (99.88%) (35862/35904)
# Epoch: 162 | Batch_idx: 570 |  Loss: (0.0075) | Acc: (99.89%) (36502/36544)
# Epoch: 162 | Batch_idx: 580 |  Loss: (0.0075) | Acc: (99.89%) (37142/37184)
# Epoch: 162 | Batch_idx: 590 |  Loss: (0.0075) | Acc: (99.89%) (37782/37824)
# Epoch: 162 | Batch_idx: 600 |  Loss: (0.0075) | Acc: (99.89%) (38422/38464)
# Epoch: 162 | Batch_idx: 610 |  Loss: (0.0075) | Acc: (99.89%) (39062/39104)
# Epoch: 162 | Batch_idx: 620 |  Loss: (0.0077) | Acc: (99.88%) (39698/39744)
# Epoch: 162 | Batch_idx: 630 |  Loss: (0.0076) | Acc: (99.89%) (40338/40384)
# Epoch: 162 | Batch_idx: 640 |  Loss: (0.0076) | Acc: (99.89%) (40978/41024)
# Epoch: 162 | Batch_idx: 650 |  Loss: (0.0075) | Acc: (99.89%) (41618/41664)
# Epoch: 162 | Batch_idx: 660 |  Loss: (0.0075) | Acc: (99.89%) (42258/42304)
# Epoch: 162 | Batch_idx: 670 |  Loss: (0.0075) | Acc: (99.89%) (42898/42944)
# Epoch: 162 | Batch_idx: 680 |  Loss: (0.0075) | Acc: (99.89%) (43538/43584)
# Epoch: 162 | Batch_idx: 690 |  Loss: (0.0076) | Acc: (99.89%) (44176/44224)
# Epoch: 162 | Batch_idx: 700 |  Loss: (0.0075) | Acc: (99.89%) (44816/44864)
# Epoch: 162 | Batch_idx: 710 |  Loss: (0.0076) | Acc: (99.89%) (45454/45504)
# Epoch: 162 | Batch_idx: 720 |  Loss: (0.0075) | Acc: (99.89%) (46094/46144)
# Epoch: 162 | Batch_idx: 730 |  Loss: (0.0075) | Acc: (99.89%) (46734/46784)
# Epoch: 162 | Batch_idx: 740 |  Loss: (0.0075) | Acc: (99.89%) (47374/47424)
# Epoch: 162 | Batch_idx: 750 |  Loss: (0.0075) | Acc: (99.90%) (48014/48064)
# Epoch: 162 | Batch_idx: 760 |  Loss: (0.0075) | Acc: (99.90%) (48653/48704)
# Epoch: 162 | Batch_idx: 770 |  Loss: (0.0075) | Acc: (99.90%) (49293/49344)
# Epoch: 162 | Batch_idx: 780 |  Loss: (0.0075) | Acc: (99.90%) (49932/49984)
# => saving checkpoint
# # TEST : Loss: (0.2639) | Acc: (93.65%) (9365/10000)
# Epoch: 163 | Batch_idx: 0 |  Loss: (0.0169) | Acc: (100.00%) (64/64)
# Epoch: 163 | Batch_idx: 10 |  Loss: (0.0086) | Acc: (99.72%) (702/704)
# Epoch: 163 | Batch_idx: 20 |  Loss: (0.0075) | Acc: (99.85%) (1342/1344)
# Epoch: 163 | Batch_idx: 30 |  Loss: (0.0073) | Acc: (99.85%) (1981/1984)
# Epoch: 163 | Batch_idx: 40 |  Loss: (0.0075) | Acc: (99.89%) (2621/2624)
# Epoch: 163 | Batch_idx: 50 |  Loss: (0.0068) | Acc: (99.91%) (3261/3264)
# Epoch: 163 | Batch_idx: 60 |  Loss: (0.0069) | Acc: (99.92%) (3901/3904)
# Epoch: 163 | Batch_idx: 70 |  Loss: (0.0067) | Acc: (99.93%) (4541/4544)
# Epoch: 163 | Batch_idx: 80 |  Loss: (0.0066) | Acc: (99.94%) (5181/5184)
# Epoch: 163 | Batch_idx: 90 |  Loss: (0.0064) | Acc: (99.95%) (5821/5824)
# Epoch: 163 | Batch_idx: 100 |  Loss: (0.0067) | Acc: (99.92%) (6459/6464)
# Epoch: 163 | Batch_idx: 110 |  Loss: (0.0066) | Acc: (99.93%) (7099/7104)
# Epoch: 163 | Batch_idx: 120 |  Loss: (0.0067) | Acc: (99.94%) (7739/7744)
# Epoch: 163 | Batch_idx: 130 |  Loss: (0.0064) | Acc: (99.94%) (8379/8384)
# Epoch: 163 | Batch_idx: 140 |  Loss: (0.0064) | Acc: (99.93%) (9018/9024)
# Epoch: 163 | Batch_idx: 150 |  Loss: (0.0063) | Acc: (99.94%) (9658/9664)
# Epoch: 163 | Batch_idx: 160 |  Loss: (0.0063) | Acc: (99.93%) (10297/10304)
# Epoch: 163 | Batch_idx: 170 |  Loss: (0.0063) | Acc: (99.93%) (10936/10944)
# Epoch: 163 | Batch_idx: 180 |  Loss: (0.0064) | Acc: (99.92%) (11575/11584)
# Epoch: 163 | Batch_idx: 190 |  Loss: (0.0063) | Acc: (99.93%) (12215/12224)
# Epoch: 163 | Batch_idx: 200 |  Loss: (0.0062) | Acc: (99.93%) (12855/12864)
# Epoch: 163 | Batch_idx: 210 |  Loss: (0.0063) | Acc: (99.93%) (13494/13504)
# Epoch: 163 | Batch_idx: 220 |  Loss: (0.0063) | Acc: (99.93%) (14134/14144)
# Epoch: 163 | Batch_idx: 230 |  Loss: (0.0063) | Acc: (99.93%) (14774/14784)
# Epoch: 163 | Batch_idx: 240 |  Loss: (0.0063) | Acc: (99.94%) (15414/15424)
# Epoch: 163 | Batch_idx: 250 |  Loss: (0.0064) | Acc: (99.93%) (16053/16064)
# Epoch: 163 | Batch_idx: 260 |  Loss: (0.0065) | Acc: (99.93%) (16692/16704)
# Epoch: 163 | Batch_idx: 270 |  Loss: (0.0064) | Acc: (99.93%) (17332/17344)
# Epoch: 163 | Batch_idx: 280 |  Loss: (0.0064) | Acc: (99.93%) (17971/17984)
# Epoch: 163 | Batch_idx: 290 |  Loss: (0.0065) | Acc: (99.92%) (18610/18624)
# Epoch: 163 | Batch_idx: 300 |  Loss: (0.0064) | Acc: (99.93%) (19250/19264)
# Epoch: 163 | Batch_idx: 310 |  Loss: (0.0066) | Acc: (99.92%) (19888/19904)
# Epoch: 163 | Batch_idx: 320 |  Loss: (0.0066) | Acc: (99.92%) (20527/20544)
# Epoch: 163 | Batch_idx: 330 |  Loss: (0.0066) | Acc: (99.92%) (21167/21184)
# Epoch: 163 | Batch_idx: 340 |  Loss: (0.0067) | Acc: (99.92%) (21806/21824)
# Epoch: 163 | Batch_idx: 350 |  Loss: (0.0067) | Acc: (99.91%) (22444/22464)
# Epoch: 163 | Batch_idx: 360 |  Loss: (0.0067) | Acc: (99.91%) (23083/23104)
# Epoch: 163 | Batch_idx: 370 |  Loss: (0.0067) | Acc: (99.91%) (23723/23744)
# Epoch: 163 | Batch_idx: 380 |  Loss: (0.0067) | Acc: (99.91%) (24363/24384)
# Epoch: 163 | Batch_idx: 390 |  Loss: (0.0067) | Acc: (99.92%) (25003/25024)
# Epoch: 163 | Batch_idx: 400 |  Loss: (0.0068) | Acc: (99.91%) (25642/25664)
# Epoch: 163 | Batch_idx: 410 |  Loss: (0.0068) | Acc: (99.91%) (26281/26304)
# Epoch: 163 | Batch_idx: 420 |  Loss: (0.0067) | Acc: (99.91%) (26921/26944)
# Epoch: 163 | Batch_idx: 430 |  Loss: (0.0066) | Acc: (99.92%) (27561/27584)
# Epoch: 163 | Batch_idx: 440 |  Loss: (0.0066) | Acc: (99.92%) (28201/28224)
# Epoch: 163 | Batch_idx: 450 |  Loss: (0.0066) | Acc: (99.92%) (28841/28864)
# Epoch: 163 | Batch_idx: 460 |  Loss: (0.0067) | Acc: (99.92%) (29479/29504)
# Epoch: 163 | Batch_idx: 470 |  Loss: (0.0067) | Acc: (99.92%) (30119/30144)
# Epoch: 163 | Batch_idx: 480 |  Loss: (0.0067) | Acc: (99.92%) (30759/30784)
# Epoch: 163 | Batch_idx: 490 |  Loss: (0.0068) | Acc: (99.91%) (31397/31424)
# Epoch: 163 | Batch_idx: 500 |  Loss: (0.0067) | Acc: (99.92%) (32037/32064)
# Epoch: 163 | Batch_idx: 510 |  Loss: (0.0068) | Acc: (99.91%) (32675/32704)
# Epoch: 163 | Batch_idx: 520 |  Loss: (0.0068) | Acc: (99.91%) (33314/33344)
# Epoch: 163 | Batch_idx: 530 |  Loss: (0.0069) | Acc: (99.91%) (33953/33984)
# Epoch: 163 | Batch_idx: 540 |  Loss: (0.0069) | Acc: (99.91%) (34593/34624)
# Epoch: 163 | Batch_idx: 550 |  Loss: (0.0069) | Acc: (99.91%) (35233/35264)
# Epoch: 163 | Batch_idx: 560 |  Loss: (0.0069) | Acc: (99.91%) (35872/35904)
# Epoch: 163 | Batch_idx: 570 |  Loss: (0.0070) | Acc: (99.90%) (36509/36544)
# Epoch: 163 | Batch_idx: 580 |  Loss: (0.0070) | Acc: (99.91%) (37149/37184)
# Epoch: 163 | Batch_idx: 590 |  Loss: (0.0070) | Acc: (99.91%) (37789/37824)
# Epoch: 163 | Batch_idx: 600 |  Loss: (0.0070) | Acc: (99.91%) (38429/38464)
# Epoch: 163 | Batch_idx: 610 |  Loss: (0.0070) | Acc: (99.91%) (39069/39104)
# Epoch: 163 | Batch_idx: 620 |  Loss: (0.0070) | Acc: (99.91%) (39708/39744)
# Epoch: 163 | Batch_idx: 630 |  Loss: (0.0071) | Acc: (99.91%) (40346/40384)
# Epoch: 163 | Batch_idx: 640 |  Loss: (0.0070) | Acc: (99.91%) (40986/41024)
# Epoch: 163 | Batch_idx: 650 |  Loss: (0.0070) | Acc: (99.91%) (41626/41664)
# Epoch: 163 | Batch_idx: 660 |  Loss: (0.0070) | Acc: (99.91%) (42265/42304)
# Epoch: 163 | Batch_idx: 670 |  Loss: (0.0070) | Acc: (99.91%) (42905/42944)
# Epoch: 163 | Batch_idx: 680 |  Loss: (0.0070) | Acc: (99.91%) (43543/43584)
# Epoch: 163 | Batch_idx: 690 |  Loss: (0.0070) | Acc: (99.91%) (44182/44224)
# Epoch: 163 | Batch_idx: 700 |  Loss: (0.0070) | Acc: (99.91%) (44822/44864)
# Epoch: 163 | Batch_idx: 710 |  Loss: (0.0070) | Acc: (99.90%) (45460/45504)
# Epoch: 163 | Batch_idx: 720 |  Loss: (0.0070) | Acc: (99.90%) (46099/46144)
# Epoch: 163 | Batch_idx: 730 |  Loss: (0.0070) | Acc: (99.90%) (46739/46784)
# Epoch: 163 | Batch_idx: 740 |  Loss: (0.0070) | Acc: (99.91%) (47379/47424)
# Epoch: 163 | Batch_idx: 750 |  Loss: (0.0070) | Acc: (99.90%) (48018/48064)
# Epoch: 163 | Batch_idx: 760 |  Loss: (0.0070) | Acc: (99.90%) (48657/48704)
# Epoch: 163 | Batch_idx: 770 |  Loss: (0.0070) | Acc: (99.90%) (49297/49344)
# Epoch: 163 | Batch_idx: 780 |  Loss: (0.0070) | Acc: (99.90%) (49935/49984)
# => saving checkpoint
# # TEST : Loss: (0.2610) | Acc: (93.62%) (9362/10000)
# Epoch: 164 | Batch_idx: 0 |  Loss: (0.0091) | Acc: (100.00%) (64/64)
# Epoch: 164 | Batch_idx: 10 |  Loss: (0.0071) | Acc: (99.86%) (703/704)
# Epoch: 164 | Batch_idx: 20 |  Loss: (0.0059) | Acc: (99.93%) (1343/1344)
# Epoch: 164 | Batch_idx: 30 |  Loss: (0.0055) | Acc: (99.95%) (1983/1984)
# Epoch: 164 | Batch_idx: 40 |  Loss: (0.0053) | Acc: (99.96%) (2623/2624)
# Epoch: 164 | Batch_idx: 50 |  Loss: (0.0054) | Acc: (99.94%) (3262/3264)
# Epoch: 164 | Batch_idx: 60 |  Loss: (0.0052) | Acc: (99.95%) (3902/3904)
# Epoch: 164 | Batch_idx: 70 |  Loss: (0.0057) | Acc: (99.93%) (4541/4544)
# Epoch: 164 | Batch_idx: 80 |  Loss: (0.0061) | Acc: (99.92%) (5180/5184)
# Epoch: 164 | Batch_idx: 90 |  Loss: (0.0058) | Acc: (99.93%) (5820/5824)
# Epoch: 164 | Batch_idx: 100 |  Loss: (0.0059) | Acc: (99.94%) (6460/6464)
# Epoch: 164 | Batch_idx: 110 |  Loss: (0.0063) | Acc: (99.93%) (7099/7104)
# Epoch: 164 | Batch_idx: 120 |  Loss: (0.0064) | Acc: (99.92%) (7738/7744)
# Epoch: 164 | Batch_idx: 130 |  Loss: (0.0068) | Acc: (99.90%) (8376/8384)
# Epoch: 164 | Batch_idx: 140 |  Loss: (0.0066) | Acc: (99.91%) (9016/9024)
# Epoch: 164 | Batch_idx: 150 |  Loss: (0.0069) | Acc: (99.91%) (9655/9664)
# Epoch: 164 | Batch_idx: 160 |  Loss: (0.0069) | Acc: (99.90%) (10294/10304)
# Epoch: 164 | Batch_idx: 170 |  Loss: (0.0072) | Acc: (99.87%) (10930/10944)
# Epoch: 164 | Batch_idx: 180 |  Loss: (0.0072) | Acc: (99.87%) (11569/11584)
# Epoch: 164 | Batch_idx: 190 |  Loss: (0.0072) | Acc: (99.88%) (12209/12224)
# Epoch: 164 | Batch_idx: 200 |  Loss: (0.0073) | Acc: (99.88%) (12848/12864)
# Epoch: 164 | Batch_idx: 210 |  Loss: (0.0074) | Acc: (99.87%) (13486/13504)
# Epoch: 164 | Batch_idx: 220 |  Loss: (0.0075) | Acc: (99.87%) (14125/14144)
# Epoch: 164 | Batch_idx: 230 |  Loss: (0.0075) | Acc: (99.86%) (14764/14784)
# Epoch: 164 | Batch_idx: 240 |  Loss: (0.0074) | Acc: (99.87%) (15404/15424)
# Epoch: 164 | Batch_idx: 250 |  Loss: (0.0074) | Acc: (99.87%) (16043/16064)
# Epoch: 164 | Batch_idx: 260 |  Loss: (0.0072) | Acc: (99.87%) (16683/16704)
# Epoch: 164 | Batch_idx: 270 |  Loss: (0.0073) | Acc: (99.87%) (17322/17344)
# Epoch: 164 | Batch_idx: 280 |  Loss: (0.0072) | Acc: (99.88%) (17962/17984)
# Epoch: 164 | Batch_idx: 290 |  Loss: (0.0071) | Acc: (99.88%) (18601/18624)
# Epoch: 164 | Batch_idx: 300 |  Loss: (0.0071) | Acc: (99.88%) (19241/19264)
# Epoch: 164 | Batch_idx: 310 |  Loss: (0.0070) | Acc: (99.88%) (19881/19904)
# Epoch: 164 | Batch_idx: 320 |  Loss: (0.0069) | Acc: (99.88%) (20520/20544)
# Epoch: 164 | Batch_idx: 330 |  Loss: (0.0069) | Acc: (99.89%) (21160/21184)
# Epoch: 164 | Batch_idx: 340 |  Loss: (0.0070) | Acc: (99.89%) (21799/21824)
# Epoch: 164 | Batch_idx: 350 |  Loss: (0.0070) | Acc: (99.88%) (22437/22464)
# Epoch: 164 | Batch_idx: 360 |  Loss: (0.0070) | Acc: (99.88%) (23077/23104)
# Epoch: 164 | Batch_idx: 370 |  Loss: (0.0070) | Acc: (99.89%) (23717/23744)
# Epoch: 164 | Batch_idx: 380 |  Loss: (0.0070) | Acc: (99.89%) (24357/24384)
# Epoch: 164 | Batch_idx: 390 |  Loss: (0.0070) | Acc: (99.89%) (24996/25024)
# Epoch: 164 | Batch_idx: 400 |  Loss: (0.0070) | Acc: (99.89%) (25635/25664)
# Epoch: 164 | Batch_idx: 410 |  Loss: (0.0070) | Acc: (99.89%) (26275/26304)
# Epoch: 164 | Batch_idx: 420 |  Loss: (0.0070) | Acc: (99.89%) (26915/26944)
# Epoch: 164 | Batch_idx: 430 |  Loss: (0.0069) | Acc: (99.89%) (27555/27584)
# Epoch: 164 | Batch_idx: 440 |  Loss: (0.0070) | Acc: (99.89%) (28194/28224)
# Epoch: 164 | Batch_idx: 450 |  Loss: (0.0070) | Acc: (99.90%) (28834/28864)
# Epoch: 164 | Batch_idx: 460 |  Loss: (0.0071) | Acc: (99.89%) (29473/29504)
# Epoch: 164 | Batch_idx: 470 |  Loss: (0.0071) | Acc: (99.90%) (30113/30144)
# Epoch: 164 | Batch_idx: 480 |  Loss: (0.0071) | Acc: (99.89%) (30751/30784)
# Epoch: 164 | Batch_idx: 490 |  Loss: (0.0071) | Acc: (99.89%) (31391/31424)
# Epoch: 164 | Batch_idx: 500 |  Loss: (0.0071) | Acc: (99.90%) (32031/32064)
# Epoch: 164 | Batch_idx: 510 |  Loss: (0.0071) | Acc: (99.90%) (32671/32704)
# Epoch: 164 | Batch_idx: 520 |  Loss: (0.0072) | Acc: (99.90%) (33310/33344)
# Epoch: 164 | Batch_idx: 530 |  Loss: (0.0072) | Acc: (99.90%) (33949/33984)
# Epoch: 164 | Batch_idx: 540 |  Loss: (0.0071) | Acc: (99.90%) (34589/34624)
# Epoch: 164 | Batch_idx: 550 |  Loss: (0.0071) | Acc: (99.90%) (35229/35264)
# Epoch: 164 | Batch_idx: 560 |  Loss: (0.0071) | Acc: (99.90%) (35869/35904)
# Epoch: 164 | Batch_idx: 570 |  Loss: (0.0071) | Acc: (99.90%) (36507/36544)
# Epoch: 164 | Batch_idx: 580 |  Loss: (0.0071) | Acc: (99.90%) (37146/37184)
# Epoch: 164 | Batch_idx: 590 |  Loss: (0.0071) | Acc: (99.90%) (37786/37824)
# Epoch: 164 | Batch_idx: 600 |  Loss: (0.0071) | Acc: (99.90%) (38426/38464)
# Epoch: 164 | Batch_idx: 610 |  Loss: (0.0071) | Acc: (99.90%) (39065/39104)
# Epoch: 164 | Batch_idx: 620 |  Loss: (0.0071) | Acc: (99.90%) (39704/39744)
# Epoch: 164 | Batch_idx: 630 |  Loss: (0.0072) | Acc: (99.90%) (40342/40384)
# Epoch: 164 | Batch_idx: 640 |  Loss: (0.0072) | Acc: (99.90%) (40982/41024)
# Epoch: 164 | Batch_idx: 650 |  Loss: (0.0071) | Acc: (99.90%) (41622/41664)
# Epoch: 164 | Batch_idx: 660 |  Loss: (0.0071) | Acc: (99.90%) (42262/42304)
# Epoch: 164 | Batch_idx: 670 |  Loss: (0.0071) | Acc: (99.90%) (42902/42944)
# Epoch: 164 | Batch_idx: 680 |  Loss: (0.0072) | Acc: (99.90%) (43540/43584)
# Epoch: 164 | Batch_idx: 690 |  Loss: (0.0071) | Acc: (99.90%) (44180/44224)
# Epoch: 164 | Batch_idx: 700 |  Loss: (0.0071) | Acc: (99.90%) (44820/44864)
# Epoch: 164 | Batch_idx: 710 |  Loss: (0.0072) | Acc: (99.90%) (45457/45504)
# Epoch: 164 | Batch_idx: 720 |  Loss: (0.0072) | Acc: (99.90%) (46096/46144)
# Epoch: 164 | Batch_idx: 730 |  Loss: (0.0072) | Acc: (99.89%) (46733/46784)
# Epoch: 164 | Batch_idx: 740 |  Loss: (0.0072) | Acc: (99.89%) (47373/47424)
# Epoch: 164 | Batch_idx: 750 |  Loss: (0.0072) | Acc: (99.89%) (48012/48064)
# Epoch: 164 | Batch_idx: 760 |  Loss: (0.0072) | Acc: (99.89%) (48651/48704)
# Epoch: 164 | Batch_idx: 770 |  Loss: (0.0072) | Acc: (99.89%) (49290/49344)
# Epoch: 164 | Batch_idx: 780 |  Loss: (0.0072) | Acc: (99.89%) (49930/49984)
# => saving checkpoint
# # TEST : Loss: (0.2621) | Acc: (93.67%) (9367/10000)
# 2 hours 21 mins 11 secs for training
